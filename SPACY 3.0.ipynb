# %% [markdown]
# <h1 style=" background-color:lightblue;color:white;font-size:100px;text-align:center">Spacy</h1>

# %%
# Spacy 3 Intallation

# !pip install pip setuptools wheel
# !pip install spacy[cuda-autodetect]
# !python -m spacy download en_core_web_trf

# %%
import spacy

# %%
# Language object
nlp = spacy.load("en_core_web_sm")

# Doc object - collection of tokens
doc = nlp("Google is looking to rent offices in Bangalore for $10Million a month") # Tokenization process

print("token.text     token.pos      token.dep_      spacy.explain(token.tag_)                     token.is_stop\n")
# POS Tagging
for token in doc:
    # these are attributes
    print(f"{token.text:<16s} {token.pos_:<14s} {token.dep_:<13s} {spacy.explain(token.tag_):<50s} {token.is_stop}")
# Out:
# token.text     token.pos      token.dep_      spacy.explain(token.tag_)                     token.is_stop
#
# Google           PROPN          nsubj         noun, proper singular                              False
# is               AUX            aux           verb, 3rd person singular present                  True
# looking          VERB           ROOT          verb, gerund or present participle                 False
# to               PART           aux           infinitival "to"                                   True
# rent             VERB           xcomp         verb, base form                                    False
# offices          NOUN           dobj          noun, plural                                       False
# in               ADP            prep          conjunction, subordinating or preposition          True
# Bangalore        PROPN          pobj          noun, proper singular                              False
# for              ADP            prep          conjunction, subordinating or preposition          True
# $                SYM            nmod          symbol, currency                                   False
# 10Million        NOUN           pobj          noun, singular or mass                             False
# a                DET            det           determiner                                         True
# month            NOUN           npadvmod      noun, singular or mass                             False

# %% [markdown]
# Dependency parsing is the process of extracting the dependency parse of a sentence to represent its grammatical structure. It defines the dependency relationship between headwords and their dependents.

# %% [markdown]
# # Parts of Speech
#
# Parts of speech are categories that help us understand the role and function of words in a sentence. There are several main parts of speech:
#
# 1. Noun: A noun is a word that represents a person, place, thing, or idea. Examples include "dog," "city," and "love."
#
# 2. Pronoun: A pronoun is a word used to replace a noun. It helps avoid repetition. Examples include "he," "she," "it," and "they."
#
# 3. Verb: A verb is a word that describes an action, state, or occurrence. It shows what the subject of the sentence is doing. Examples include "run," "eat," and "sleep."
#
# 4. Adjective: An adjective is a word that describes or modifies a noun. It provides more information about the noun. Examples include "happy," "big," and "red."
#
# 5. Adverb: An adverb is a word that describes or modifies a verb, adjective, or other adverb. It provides more information about how, when, or where something happens. Examples include "quickly," "very," and "often."
#
# 6. Preposition: A preposition is a word that shows a relationship between a noun or pronoun and another word in the sentence. It indicates location, direction, time, or manner. Examples include "in," "on," "at," and "with."
#
# 7. Conjunction: A conjunction is a word that connects words, phrases, or clauses in a sentence. It shows relationships between them. Examples include "and," "but," "or," and "because."
#
# 8. Interjection: An interjection is a word or phrase used to express strong emotions or surprise. It often stands alone and is followed by an exclamation mark. Examples include "wow," "oh," and "ouch."

# %% [markdown]
# # Visualizing the Dependency Parsing

# %%
from spacy import displacy
displacy.render(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is looking to rent offices in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bangalore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10Million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  a month</div></span>

# %%
options = {"distance":120, "bg":"#0095b6", "color":"#DDDDDD", "font":"Source Sans Pro"}
displacy.render(doc, style='dep', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2d7e02b259b44bfebca43ca59a4ea41b-0" class="displacy" width="1610" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #DDDDDD; background: #0095b6; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">rent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">offices</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Bangalore</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">10Million</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">month</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-0" stroke-width="2px" d="M70,122.0 C70,2.0 290.0,2.0 290.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-2" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-3" stroke-width="2px" d="M310,122.0 C310,2.0 530.0,2.0 530.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,124.0 L538.0,112.0 522.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-4" stroke-width="2px" d="M550,122.0 C550,62.0 645.0,62.0 645.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,124.0 L653.0,112.0 637.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-5" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,124.0 L773.0,112.0 757.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-6" stroke-width="2px" d="M790,122.0 C790,62.0 885.0,62.0 885.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M885.0,124.0 L893.0,112.0 877.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-7" stroke-width="2px" d="M550,122.0 C550,2.0 1010.0,2.0 1010.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2d7e02b259b44bfebca43ca59a4ea41b-0-7" class="displacy-label" startOffset="50%

# %% [markdown]
# ### Entity Vs Token
#
# A <b>token</b> is the smallest unit of text that NLP systems analyze. It can be a word, a number, or even a punctuation mark. Tokens are like individual puzzle pieces that make up a sentence. For example, in the sentence "I love cats," the tokens are "I," "love," and "cats."
#
# An <b>entity</b> refers to something specific mentioned in the text that has a particular meaning or significance. Entities are usually named objects, such as people, organizations, locations, dates, or other types of nouns. NLP systems often identify and classify entities to understand the context and extract meaningful information from the text.
#
# To illustrate, in the sentence "John works at Google," the tokens are "John," "works," "at," and "Google." The entity in this sentence is "Google," which refers to a specific organization.
#
# In summary, tokens are the individual units of text used for analysis, while entities are specific named objects or elements within the text that carry meaning and are often classified by NLP systems.

# %% [markdown]
# # Sentence Boundary Detection

# %% [markdown]
# Detecting start & end of the sentences. Extracting sentences from a paragraph.

# %%
para = '''Tap to Pay on ‌iPhone‌ is set to compete against existing ‌iPhone‌ payment solutions for merchants such as Square. It will let small businesses accept NFC contactless payments through supported iOS apps with an ‌iPhone‌ XS or newer. When checking someone out, the merchant will ask the customer to hold their own ‌iPhone‌, Apple Watch, digital wallet, or contactless card up to the merchant's ‌iPhone‌ to complete a payment quickly and easily.'''
doc = nlp(para)

#doc.sents extract the sentences from the paragraph
sentences = doc.sents
for s in sentences:
    print(s)
# Out:
# Tap to Pay on ‌iPhone‌ is set to compete against existing ‌iPhone‌ payment solutions for merchants such as Square.
# It will let small businesses accept NFC contactless payments through supported iOS apps with an ‌iPhone‌ XS or newer.
# When checking someone out, the merchant will ask the customer to hold their own ‌iPhone‌, Apple Watch, digital wallet, or contactless card up to the merchant's ‌iPhone‌ to complete a payment quickly and easily.

# %% [markdown]
# # Stopwords

# %% [markdown]
# Common words in english language that occur most frequently

# %%
stopwords = spacy.lang.en.stop_words.STOP_WORDS # returns SET of stopwords 
list(stopwords)[:10]
# Out:
# ['another',
#  'thus',
#  'thereupon',
#  'will',
#  'was',
#  'next',
#  'done',
#  'whence',
#  'few',
#  'other']

# %%
doc
# Out:
# Tap to Pay on ‌iPhone‌ is set to compete against existing ‌iPhone‌ payment solutions for merchants such as Square. It will let small businesses accept NFC contactless payments through supported iOS apps with an ‌iPhone‌ XS or newer. When checking someone out, the merchant will ask the customer to hold their own ‌iPhone‌, Apple Watch, digital wallet, or contactless card up to the merchant's ‌iPhone‌ to complete a payment quickly and easily.

# %%
for sentence in doc.sents:
    for token in sentence:
        print(token)
    break # added to print a single line
# Out:
# Tap
# to
# Pay
# on
# ‌iPhone‌
# is
# set
# to
# compete
# against
# existing
# ‌iPhone‌
# payment
# solutions
# for
# merchants
# such
# as
# Square
# .

# %%
# Removing stopwords from paragraph
for sentence in doc.sents:
    for token in sentence:
        if token.text not in stopwords: # token.text contains the value of the token
            print(token)
    break
# Out:
# Tap
# Pay
# ‌iPhone‌
# set
# compete
# existing
# ‌iPhone‌
# payment
# solutions
# merchants
# Square
# .

# %%
sentence # sentence is the part of the doc object which can be further divided into tokens
# Out:
# Tap to Pay on ‌iPhone‌ is set to compete against existing ‌iPhone‌ payment solutions for merchants such as Square.

# %%
sentence.text # textual Value of the sentence
# Out:
# 'Tap to Pay on \u200ciPhone\u200c is set to compete against existing \u200ciPhone\u200c payment solutions for merchants such as Square.'

# %% [markdown]
# # Lemmatization

# %% [markdown]
# Lemmatization is a language processing technique that finds the base or dictionary form of a word, which is called the "lemma." It considers the context and grammar of the word to determine its simplest form. Lemmatization takes into account things like tense, pluralization, and other variations to transform words into their fundamental form. For example, it can convert words like "cars," "car's," and "cars'" to their common lemma "car." Lemmatization helps us understand that different forms of a word have the same meaning, making it easier for computers and people to work with words more effectively.

# %% [markdown]
# <pre>
# 1. Base or root word with similar meaning
# 2. Creates a lemma which is the root form of word
# 3. More accurate than stemming
# </pre>

# %%
# Token -> Lemmatization -> Lemma(base or root word with similar meaning)
line = nlp("looking look run ran running ")

for token in line:
    print(f"{token.text:<10s} {token.lemma_:<10s}")
# Out:
# looking    look
# look       look
# run        run
# ran        run
# running    run

# %% [markdown]
# # Stemming

# %% [markdown]
# Stemming is a language processing technique that helps us find the root or base form of a word by removing extra parts, like endings or suffixes. It simplifies words so we can group together similar words that share the same core meaning. For example, stemming can turn words like "running," "ran," and "runs" into their common form "run." It makes it easier for us to understand and work with words in a simpler way.

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

line = nlp('study studying studied')

for token in line:
    print(f"{token.text:<10s} {ps.stem(token.text)}")
# Out:
# study      studi
# studying   studi
# studied    studi

# %% [markdown]
# # Word Frequency Count

# %%
from collections import Counter

# %%
Counter(para.split())
# Out:
# Counter({'Tap': 1,
#          'to': 5,
#          'Pay': 1,
#          'on': 1,
#          '\u200ciPhone\u200c': 4,
#          'is': 1,
#          'set': 1,
#          'compete': 1,
#          'against': 1,
#          'existing': 1,
#          'payment': 2,
#          'solutions': 1,
#          'for': 1,
#          'merchants': 1,
#          'such': 1,
#          'as': 1,
#          'Square.': 1,
#          'It': 1,
#          'will': 2,
#          'let': 1,
#          'small': 1,
#          'businesses': 1,
#          'accept': 1,
#          'NFC': 1,
#          'contactless': 2,
#          'payments': 1,
#          'through': 1,
#          'supported': 1,
#          'iOS': 1,
#          'apps': 1,
#          'with': 1,
#          'an': 1,
#          'XS': 1,
#          'or': 2,
#          'newer.': 1,
#          'When': 1,
#          'checking': 1,
#          'someone': 1,
#          'out,': 1,
#          'the': 3,
#          'merchant': 1,
#          'ask': 1,
#          'customer': 1,
#          'hold': 1,
#          'their': 1,
#          'own': 1,
#          '\u200ciPhone\u200c,': 1,
#          'Apple': 1,
#          'Watch,': 1,
#          'digital': 1,
#          'wallet,': 1,
#          'card': 1,
#          'up': 1,
#          "merchant's": 1,
#          'complete': 1,
#          'a': 1,
#          'quickly': 1,
#          'and': 1,
#          'easily.': 1})

# %%
word_freq = Counter(para.split())
word_freq.most_common(10)
# Out:
# [('to', 5),
#  ('\u200ciPhone\u200c', 4),
#  ('the', 3),
#  ('payment', 2),
#  ('will', 2),
#  ('contactless', 2),
#  ('or', 2),
#  ('Tap', 1),
#  ('Pay', 1),
#  ('on', 1)]

# %% [markdown]
# # Rule Based Matching

# %%
# Getting Alice - Adventures in Wonderland ebook 
import requests
response = requests.get('https://www.gutenberg.org/files/11/11-0.txt')
response.text
# Out:
# 'ï»¿The Project Gutenberg eBook of Aliceâ\x80\x99s Adventures in Wonderland, by Lewis Carroll\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org. If you are not located in the United States, you\r\nwill have to check the laws of the country where you are located before\r\nusing this eBook.\r\n\r\nTitle: Aliceâ\x80\x99s Adventures in Wonderland\r\n\r\nAuthor: Lewis Carroll\r\n\r\nRelease Date: January, 1991 [eBook #11]\r\n[Most recently updated: October 12, 2020]\r\n\r\nLanguage: English\r\n\r\nCharacter set encoding: UTF-8\r\n\r\nProduced by: Arthur DiBianca and David Widger\r\n\r\n*** START OF THE PROJECT GUTENBERG EBOOK ALICEâ\x80\x99S ADVENTURES IN WONDERLAND ***\r\n\r\n[Illustration]\r\n\r\n\r\n\r\n\r\nAliceâ\x80\x99s Adventures in Wonderland\r\n\r\nby Lewis Carroll\r\n\r\nTHE MILLENNIUM FULCRUM EDITION 3.0\r\n\r\nContents\r\n\r\n CHAPTER I.     Down the Rabbit-Hole\r\n CHAPTER II.    The Pool of Tears\r\n CHAPTER III.   A Caucus-Race and a Long Tale\r\n CHAPTER IV.    The Rabbit Sends in a Little Bill\r\n CHAPTER V.     Advice from a Caterpillar\r\n CHAPTER VI.    Pig and Pepper\r\n CHAPTER VII.   A Mad Tea-Party\r\n CHAPTER VIII.  The Queenâ\x80\x99s Croquet-Ground\r\n CHAPTER IX.    The Mock Turtleâ\x80\x99s Story\r\n CHAPTER X.     The Lobster Quadrille\r\n CHAPTER XI.    Who Stole the Tarts?\r\n CHAPTER XII.   Aliceâ\x80\x99s Evidence\r\n\r\n\r\n\r\n\r\nCHAPTER I.\r\nDown the Rabbit-Hole\r\n\r\n\r\nAlice was beginning to get very tired of sitting by her sister on the\r\nbank, and of having nothing to do: once or twice she had peeped into\r\nthe book her sister was reading, but it had no pictures or\r\nconversations in it, â\x80\x9cand what is the use of a book,â\x80\x9d thought Alice\r\nâ\x80\x9cwithout pictures or conversations?â\x80\x9d\r\n\r\nSo she was considering in her own mind (as well as she could, for the\r\nhot day made her feel very sleepy and stupid), whether the pleasure of\r\nmaking a daisy-chain would be worth the trouble of getting up and\r\npicking the daisies, when suddenly a White Rabbit with pink eyes ran\r\nclose by her.\r\n\r\nThere was nothing so _very_ remarkable in that; nor did Alice think it\r\nso _very_ much out of the way to hear the Rabbit say to itself, â\x80\x9cOh\r\ndear! Oh dear! I shall be late!â\x80\x9d (when she thought it over afterwards,\r\nit occurred to her that she ought to have wondered at this, but at the\r\ntime it all seemed quite natural); but when the Rabbit actually _took a\r\nwatch out of its waistcoat-pocket_, and looked at it, and then hurried\r\non, Alice started to her feet, for it flashed across her mind that she\r\nhad never before seen a rabbit with either a waistcoat-pocket, or a\r\nwatch to take out of it, and burning with curiosity, she ran across the\r\nfield after it, and fortunately was just in time to see it pop down a\r\nlarge rabbit-hole under the hedge.\r\n\r\nIn another moment down went Alice after it, never once considering how\r\nin the world she was to get out again.\r\n\r\nThe rabbit-hole went straight on like a tunnel for some way, and then\r\ndipped suddenly down, so suddenly that Alice had not a moment to think\r\nabout stopping herself before she found herself falling down a very\r\ndeep well.\r\n\r\nEither the well was very deep, or she fell very slowly, for she had\r\nplenty of time as she went down to look about her and to wonder what\r\nwas going to happen next. First, she tried to look down and make out\r\nwhat she was coming to, but it was too dark to see anything; then she\r\nlooked at the sides of the well, and noticed that they were filled with\r\ncupboards and book-shelves; here and there she saw maps and pictures\r\nhung upon pegs. She took down a jar from one of the ...

# %%
doc = nlp(response.text)

# %%
displacy.render(doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ï»¿The
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Project
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gutenberg eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aliceâs Adventures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lewis Carroll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>This
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  is for the use of anyone anywhere in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>of the Project Gutenberg License included with this
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>www.gutenberg.org. If you are not located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>using this
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>Title:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aliceâs Adventures
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Author:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lewis Carroll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Release Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     January, 1991
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  [
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook #11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# </br>[Most recently updated:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October 12, 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>Language:
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# </br>Produced by:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arthur DiBianca
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Widger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>*** START OF THE PROJECT GUTENBERG EBOOK ALICEâS
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ADVENTURES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>Aliceâs Adventures in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wonderland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lewis Carroll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>THE MILLENNIUM FULCRUM EDITION
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br> CHAPTER III.   A
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Caucus-Race
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br> CHAPTER V.     Advice from a
# <mark class="entity" style="backgroun

# %%
for token in doc:
    print(f"{token.text:<25s}{token.pos_}" )
# Out:
# ï»¿The                   NUM
# Project                  PROPN
# Gutenberg                PROPN
# eBook                    PROPN
# of                       ADP
# Aliceâs                PROPN
# Adventures               PROPN
# in                       ADP
# Wonderland               PROPN
# ,                        PUNCT
# by                       ADP
# Lewis                    PROPN
# Carroll                  PROPN
#
#
#                      SPACE
# This                     DET
# eBook                    PROPN
# is                       AUX
# for                      ADP
# the                      DET
# use                      NOUN
# of                       ADP
# anyone                   PRON
# anywhere                 ADV
# in                       ADP
# the                      DET
# United                   PROPN
# States                   PROPN
# and                      CCONJ
#
#                        SPACE
# most                     ADJ
# other                    ADJ
# parts                    NOUN
# of                       ADP
# the                      DET
# world                    NOUN
# at                       ADP
# no                       DET
# cost                     NOUN
# and                      CCONJ
# with                     ADP
# almost                   ADV
# no                       PRON
# restrictions             NOUN
#
#                        SPACE
# whatsoever               ADV
# .                        PUNCT
# You                      PRON
# may                      AUX
# copy                     VERB
# it                       PRON
# ,                        PUNCT
# give                     VERB
# it                       PRON
# away                     ADV
# or                       CCONJ
# re                       VERB
# -                        VERB
# use                      VERB
# it                       PRON
# under                    ADP
# the                      DET
# terms                    NOUN
#
#                        SPACE
# of                       ADP
# the                      DET
# Project                  PROPN
# Gutenberg                PROPN
# License                  PROPN
# included                 VERB
# with                     ADP
# this                     DET
# eBook                    PROPN
# or                       CCONJ
# online                   NOUN
# at                       ADP
#
#                        SPACE
# www.gutenberg.org        NUM
# .                        PUNCT
# If                       SCONJ
# you                      PRON
# are                      AUX
# not                      PART
# located                  VERB
# in                       ADP
# the                      DET
# United                   PROPN
# States                   PROPN
# ,                        PUNCT
# you                      PRON
#
#                        SPACE
# will                     AUX
# have                     VERB
# to                       PART
# check                    VERB
# the                      DET
# laws                     NOUN
# of                       ADP
# the                      DET
# country                  NOUN
# where                    SCONJ
# you                      PRON
# are                      AUX
# located                  VERB
# before                   ADP
#
#                        SPACE
# using                    VERB
# this                     DET
# eBook                    PROPN
# .                        PUNCT
#
#
#                      SPACE
# Title                    NOUN
# :                        PUNCT
# Aliceâs                PUNCT
# Adventures               PROPN
# in                       ADP
# Wonderland               PROPN
#
#
#                      SPACE
# Author                   PROPN
# :                        PUNCT
# Lewis                    PROPN
# Carroll                  PROPN
#
#
#                      SPACE
# Release                  PROPN
# Date                     PROPN
# :                        PUNCT
# January                  PROPN
# ,                        PUNCT
# 1991                     NUM
# [                        X
# eBook                    VERB
# #                        SYM
# 11                       NUM
# ]                        PUNCT
#
#                        SPACE
# [                        X
# Most                     ADV
# recently                 ADV
# updated                  VERB
# :                        PUNCT
# October                  PROPN
# 12                       NUM
# ,                        PUNCT
# 2020                     NUM
# ]                        PUNCT
#
#
#                      SPACE
# Language                 NOUN
# :                        PUNCT
# English                  PROPN
#
#
#                      SPACE
# Character                PROPN
# set                      VERB
# encoding                 NOUN
# :                        PUNCT
# UTF-8                    PROPN
#
#
#                      SPACE
# Produced                 VERB
# by                       ADP
# :                        PUNCT
# Arthur                   PROPN
# DiBianca                 PROPN
# and                      CCONJ
# David                    PROPN
# Widger                   PROPN
#
#
#                      SPACE
# *                        PUNCT
# *                        PUNCT
# *                        ADJ
# START                    NOUN
# OF                       ADP
# THE                      DET
# PROJECT                  PROPN
# GUTENBERG                PROPN
# EBOOK                    VERB
# ALICEâS                PROPN
# ADVENTURES               NOUN
# IN                       ADP
# WONDERLAND               PROPN
# *                        PUNCT
# *                        PUNCT
# *                        PUNCT
#
#
#                      SPACE
# [                        X
# Illustration             NOUN
# ]                        PUNCT
#
#
#
#
#
#                SPACE
# Aliceâs                PROPN
# Adventures               PROPN
# in                       ADP
# Wonderland               PROPN
#
#
#                      SPACE
# by                       ADP
# Lewis                    PROPN
# Carroll                  PROPN
#
#
#                      SPACE
# THE                      DET
# MILLENNIUM               PROPN
# FULCRUM                  PROPN
# EDITION                  PROPN
# 3.0                      NUM
#
#
#                      SPACE
# Contents                 PROPN
#
#
#                      SPACE
# CHAPTER                  PROPN
# I.                       PROPN
#                          SPACE
# Down                     ADP
# the                      DET
# Rabbit                   PROPN
# -                        PUNCT
# Hole                     PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# II                       PROPN
# .                        PUNCT
#                          SPACE
# The                      DET
# Pool                     PROPN
# of                       ADP
# Tears                    PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# III                      PROPN
# .                        PUNCT
#                          SPACE
# A                        DET
# Caucus                   PROPN
# -                        PUNCT
# Race                     PROPN
# and                      CCONJ
# a                        DET
# Long                     PROPN
# Tale                     PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# IV                       PROPN
# .                        PUNCT
#                          SPACE
# The                      DET
# Rabbit                   PROPN
# Sends                    PROPN
# in                       ADP
# a                        DET
# Little                   PROPN
# Bill                     PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# V.                       PROPN
#                          SPACE
# Advice                   PROPN
# from                     ADP
# a                        DET
# Caterpillar              PROPN
#
#                        SPACE
# CHAPTER                  NOUN
# VI                       PROPN
# .                        PUNCT
#                          SPACE
# Pig                      PROPN
# and                      CCONJ
# Pepper                   PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# VII                      PROPN
# .                        PUNCT
#                          SPACE
# A                        DET
# Mad                      ADJ
# Tea                      PROPN
# -                        PUNCT
# Party                    PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# VIII                     PROPN
# .                        PUNCT
#                          SPACE
# The                      DET
# Queenâs                NOUN
# Croquet                  PROPN
# -                        PUNCT
# Ground                   PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# IX                       PROPN
# .                        PUNCT
#                          SPACE
# The                      DET
# Mock                     PROPN
# Turtleâs               NOUN
# Story                    NOUN
#
#                        SPACE
# CHAPTER                  NOUN
# X.                       PROPN
#                          SPACE
# The                      DET
# Lobster                  PROPN
# Quadrille                PROPN
#
#                        SPACE
# CHAPTER                  PROPN
# XI                       PROPN
# .                        PUNCT
#                          SPACE
# Who                      PRON
# Stole                    VERB
# the                      DET
# Tarts                    PROPN
# ?                        PUNCT
#
#                        SPACE
# CHAPTER                  PROPN
# XII                      PROPN
# .                        PUNCT
#                          SPACE
# Aliceâs                X
# Evidence                 PROPN
#
#
#
#
#
#                SPACE
# CHAPTER                  PROPN
# I.                       PROPN
#
#                        SPACE
# Down                     ADP
# the                      DET
# Rabbit                   PROPN
# -                        PUNCT
# Hole                     PROPN
#
#
#
#                    SPACE
# Alice                    PROPN
# was                      AUX
# beginning                VERB
# to                       PART
# get                      VERB
# very                     ADV
# tired                    ADJ
# of                       ADP
# sitting                  VERB
# by                       ADP
# her                      PRON
# sister                   NOUN
# on                       ADP
# the                      DET
#
#                        SPACE
# bank                     NOUN
# ,                        PUNCT
# and                      CCONJ
# of                       ADP
# having                   VERB
# nothing                  PRON
# to                       PART
# do                       VERB
# :                        PUNCT
# once                     ADV
# or                       CCONJ
# twice                    ADV
# she                      PRON
# had                      AUX
# peeped                   VERB
# into                     ADP
#
#                        SPACE
# the                      DET
# book                     NOUN
# her                      PRON
# sister                   NOUN
# was                      AUX
# reading                  VERB
# ,                        PUNCT
# but                      CCONJ
# it                       PRON
# had                      VERB
# no                       DET
# pictures                 NOUN
# or                       CCONJ
#
#                        SPACE
# conversations            NOUN
# in                       ADP
# it                       PRON
# ,                        PUNCT
# âand                   CCONJ
# what                     PRON
# is                       AUX
# the                      DET
# use                      NOUN
# of                       ADP
# a                        DET
# book                     NOUN
# ,                        PUNCT
# â                      PROPN
# thought                  VERB
# Alice                    PROPN
#
#                        SPACE
# âwithout               NOUN
# pictures                 NOUN
# or                       CCONJ
# conversations?â        NOUN
#
#
#                      SPACE
# So                       ADV
# she                      PRON
# was                      AUX
# considering              VERB
# in                       ADP
# her                      PRON
# own                      ADJ
# mind                     NOUN
# (                        PUNCT
# as                       ADV
# well                     ADV
# as                       SCONJ
# she                      PRON
# could                    AUX
# ,                        PUNCT
# for                      ADP
# the                      DET
#
#                        SPACE
# hot                      ADJ
# day                      NOUN
# made                     VERB
# her                      PRON
# feel                     VERB
# very                     ADV
# sleepy                   ADJ
# and                      CCONJ
# stupid                   ADJ
# )                        PUNCT
# ,                        PUNCT
# whether                  SCONJ
# the                      DET
# pleasure                 NOUN
# of                       ADP
#
#                        SPACE
# making                   VERB
# a                        DET
# daisy                    NOUN
# -                        PUNCT
# chain                    NOUN
# would                    AUX
# be                       AUX
# worth                    ADJ
# the                      DET
# trouble                  NOUN
# of                       ADP
# getting                  VERB
# up                       ADP
# and                      CCONJ
#
#                        SPACE
# picking                  VERB
# the                      DET
# daisies                  NOUN
# ,                        PUNCT
# when                     SCONJ
# suddenly                 ADV
# a                        DET
# White                    PROPN
# Rabbit                   PROPN
# with                     ADP
# pink                     ADJ
# eyes                     NOUN
# ran                      VERB
#
#                        SPACE
# close                    ADJ
# by                       ADP
# her                      PRON
# .                        PUNCT
#
#
#                      SPACE
# There                    PRON
# was                      VERB
# nothing                  PRON
# so                       ADV
# _                        ADV
# very                     ADV
# _                        ADV
# remarkable               ADJ
# in                       ADP
# that                     PRON
# ;                        PUNCT
# nor                      CCONJ
# did                      AUX
# Alice                    PROPN
# think                    VERB
# it                       PRON
#
#                        SPACE
# so                       ADV
# _                        ADV
# very                     ADV
# _                        ADV
# much                     ADV
# out                      ADP
# of                       ADP
# the                      DET
# way                      NOUN
# to                       PART
# hear                     VERB
# the                      DET
# Rabbit                   PROPN
# say                      VERB
# to                       ADP
# itself                   PRON
# ,                        PUNCT
# âOh                    PROPN
#
#                        SPACE
# dear                     NOUN
# !                        PUNCT
# Oh                       INTJ
# dear                     INTJ
# !                        PUNCT
# I                        PRON
# shall                    AUX
# be                       AUX
# late!â                 ADJ
# (                        PUNCT
# when                     SCONJ
# she                      PRON
# thought                  VERB
# it                       PRON
# over                     ADP
# afterwards               ADV
# ,                        PUNCT
#
#                        SPACE
# it                       PRON
# occurred                 VERB
# to                       ADP
# her                      PRON
# that                     SCONJ
# she                      PRON
# ought                    AUX
# to                       PART
# have                     AUX
# wondered                 VERB
# at                       ADP
# this                     PRON
# ,                        PUNCT
# but                      CCONJ
# at                       ADP
# the                      DET
#
#                        SPACE
# time                     NOUN
# it                       PRON
# all                      PRON
# seemed                   VERB
# quite                    ADV
# natural                  ADJ
# )                        PUNCT
# ;                        PUNCT
# but                      CCONJ
# when                     SCONJ
# the                      DET
# Rabbit                   PROPN
# actually                 ADV
# _                        PRON
# took                     VERB
# a                        DET
#
#                        SPACE
# watch                    NOUN
# out                      ADP
# of                       ADP
# its                      PRON
# waistcoat                NOUN
# -                        PUNCT
# pocket                   NOUN
# _                        NOUN
# ,                        PUNCT
# and                      CCONJ
# looked                   VERB
# at                       ADP
# it                       PRON
# ,                        PUNCT
# and                      CCONJ
# then                     ADV
# hurried                  VERB
#
#                        SPACE
# on                       ADP
# ,                        PUNCT
# Alice                    PROPN
# started                  VERB
# to                       ADP
# her                      PRON
# feet                     NOUN
# ,                        PUNCT
# for                      SCONJ
# it                       PRON
# flashed                  VERB
# across                   ADP
# her                      PRON
# mind                     NOUN
# that                     SCONJ
# she                      PRON
#
#                        SPACE
# had                      AUX
# never                    ADV
# before                   ADV
# seen                     VERB
# a                        DET
# rabbit                   NOUN
# with                     ADP
# either                   CCONJ
# a                        DET
# waistcoat                NOUN
# -                        PUNCT
# pocket                   NOUN
# ,                        PUNCT
# or                       CCONJ
# a                        DET
#
#                        SPACE
# watch                    NOUN
# to                       PART
# take                     VERB
# out                      ADP
# of                       ADP
# it                       PRON
# ,                        PUNCT
# and                      CCONJ
# burning                  VERB
# with                     ADP
# curiosity                NOUN
# ,                        PUNCT
# she                      PRON
# ran                      VERB
# across                   ADP
# the                      DET
#
#                        SPACE
# field                    NOUN
# after                    ADP
# it                       PRON
# ,                        PUNCT
# and                      CCONJ
# fortunately              ADV
# was                      AUX
# just                     ADV
# in                       ADP
# time                     NOUN
# to                       PART
# see                      VERB
# it                       PRON
# pop                      VERB
# down                     ADP
# a                        DET
#
#                        SPACE
# large                    ADJ
# rabbit                   NOUN
# -                        PUNCT
# hole                     NOUN
# under                    ADP
# the                      DET
# hedge                    NOUN
# .                        PUNCT
#
#
#                      SPACE
# In                       ADP
# another                  DET
# moment                   NOUN
# down                     ADV
# went                     VERB
# Alice                    PROPN
# after                    ADP
# it                       PRON
# ,                        PUNCT
# never                    ADV
# once                     ADV
# considering              VERB
# how                      SCONJ
#
#                        SPACE
# in                       ADP
# the                      DET
# world                    NOUN
# she                      PRON
# was                      AUX
# to                       PART
# get                      VERB
# out                      ADP
# again                    ADV
# .                        PUNCT
#
#
#                      SPACE
# The                      DET
# rabbit                   NOUN
# -                        PUNCT
# hole                     NOUN
# went                     VERB
# straight                 ADV
# on                       ADV
# like                     ADP
# a                        DET
# tunnel                   NOUN
# for                      ADP
# some                     DET
# way                      NOUN
# ,                        PUNCT
# and                      CCONJ
# then                     ADV
#
#                        SPACE
# dipped                   VERB
# suddenly                 ADV
# down                     ADV
# ,                        PUNCT
# so                       ADV
# suddenly                 ADV
# that                     SCONJ
# Alice                    PROPN
# had                      VERB
# not                      PART
# a                        DET
# moment                   NOUN
# to                       PART
# think                    VERB
#
#                        SPACE
# about                    ADP
# stopping                 VERB
# herself                  PRON
# before                   SCONJ
# she                      PRON
# found                    VERB
# herself                  PRON
# falling                  VERB
# down                     ADP
# a                        DET
# very                     ADV
#
#                        SPACE
# deep                     ADJ
# well                     ADV
# .                        PUNCT
#
#
#                      SPACE
# Either                   CCONJ
# the                      DET
# well                     NOUN
# was                      AUX
# very                     ADV
# deep                     ADJ
# ,                        PUNCT
# or                       CCONJ
# she                      PRON
# fell                     VERB
# very                     ADV
# slowly                   ADV
# ,                        PUNCT
# for                      SCONJ
# she                      PRON
# had                      VERB
#
#                        SPACE
# plenty                   NOUN
# of                       ADP
# time                     NOUN
# as                       SCONJ
# she                      PRON
# went                     VERB
# down                     ADP
# to                       PART
# look                     VERB
# about                    ADP
# her                      PRON
# and                      CCONJ
# to                       PART
# wonder                   VERB
# what                     PRON
#
#                        SPACE
# was                      AUX
# going                    VERB
# to                       PART
# happen                   VERB
# next                     ADV
# .                        PUNCT
# First                    ADV
# ,                        PUNCT
# she                      PRON
# tried                    VERB
# to                       PART
# look                     VERB
# down                     ADP
# and                      CCONJ
# make                     VERB
# out                      ADP
#
#                        SPACE
# what                     PRON
# she                      PRON
# was                      AUX
# coming                   VERB
# to                       ADP
# ,                        PUNCT
# but                      CCONJ
# it                       PRON
# was                      AUX
# too                      ADV
# dark                     ADJ
# to                       PART
# see                      VERB
# anything                 PRON
# ;                        PUNCT
# then                     ADV
# she                      PRON
#
#                        SPACE
# looked                   VERB
# at                       ADP
# the                      DET
# sides                    NOUN
# of                       ADP
# the                      DET
# well                     NOUN
# ,                        PUNCT
# and                      CCONJ
# noticed                  VERB
# that                     SCONJ
# they                     PRON
# were                     AUX
# filled                   VERB
# with                     ADP
#
#                        SPACE
# cupboards                NOUN
# and                      CCONJ
# book                     NOUN
# -                        PUNCT
# shelves                  NOUN
# ;                        PUNCT
# here                     ADV
# and                      CCONJ
# there                    ADV
# she                      PRON
# saw                      VERB
# maps                     NOUN
# and                      CCONJ
# pictures                 NOUN
#
#                        SPACE
# hung                     VERB
# upon                     SCONJ
# pegs                     NOUN
# .                        PUNCT
# She                      PRON
# took                     VERB
# down                     ADP
# a                        DET
# jar                      NOUN
# from                     ADP
# one                      NUM
# of                       ADP
# the                      DET
# shelves                  NOUN
# as                       SCONJ
# she                      PRON
#
#                        SPACE
# passed                   VERB
# ;                        PUNCT
# it                       PRON
# was                      AUX
# labelled                 VERB
# âORANGE                PROPN
# MARMALADEâ             PROPN
# ,                        PUNCT
# but                      CCONJ
# to                       ADP
# her                      PRON
# great                    ADJ
#
#                        SPACE
# disappointment           NOUN
# it                       PRON
# was                      AUX
# empty                    ADJ
# :                        PUNCT
# she                      PRON
# did                      AUX
# not                      PART
# like                     VERB
# to                       PART
# drop                     VERB
# the                      DET
# jar                      NOUN
# for                      ADP
# fear                     NOUN
#
#                        SPACE
# of                       ADP
# killing                  VERB
# somebody                 PRON
# underneath               ADV
# ,                        PUNCT
# so                       ADV
# managed                  VERB
# to                       PART
# put                      VERB
# it                       PRON
# into                     ADP
# one                      NUM
# of                       ADP
# the                      DET
#
#                        SPACE
# cupboards                NOUN
# as                       SCONJ
# she                      PRON
# fell                     VERB
# past                     ADP
# it                       PRON
# .                        PUNCT
#
#
#                      SPACE
# âWell!â              NUM
# thought                  VERB
# Alice                    PROPN
# to                       ADP
# herself                  PRON
# ,                        PUNCT
# âafter                 VERB
# such                     DET
# a                        DET
# fall                     NOUN
# as                       ADP
# this                     PRON
# ,                        PUNCT
# I                        PRON
# shall                    AUX
#
#                        SPACE
# think                    VERB
# nothing                  PRON
# of                       ADP
# tumbling                 VERB
# down                     ADP
# stairs                   NOUN
# !                        PUNCT
# How                      SCONJ
# brave                    ADJ
# theyâll                NOUN
# all                      PRON
# think                    VERB
# me                       PRON
#
#                        SPACE
# at                       ADP
# home                     NOUN
# !                        PUNCT
# Why                      SCONJ
# ,                        PUNCT
# I                        PRON
# wouldnât               AUX
# say                      VERB
# anything                 PRON
# about                    ADP
# it                       PRON
# ,                        PUNCT
# even                     ADV
# if                       SCONJ
# I                        PRON
# fell                     VERB
# off                      ADP
# the                      DET
#
#                        SPACE
# top                      NOUN
# of                       ADP
# the                      DET
# house!â                NOUN
# (                        PUNCT
# Which                    PRON
# was                      AUX
# very                     ADV
# likely                   ADJ
# true                     ADJ
# .                        PUNCT
# )                        PUNCT
#
#
#                      SPACE
# Down                     ADV
# ,                        PUNCT
# down                     ADV
# ,                        PUNCT
# down                     ADV
# .                        PUNCT
# Would                    AUX
# the                      DET
# fall                     NOUN
# _                        ADV
# never                    ADV
# _                        PROPN
# come                     VERB
# to                       ADP
# an                       DET
# end                      NOUN
# ?                        PUNCT
# âI                     PRON
# wonder                   VERB
# how                      SCONJ
#
#                        SPACE
# many                     ADJ
# miles                    NOUN
# Iâve                   NUM
# fallen                   VERB
# by                       ADP
# this                     DET
# time?â                 NOUN
# she                      PRON
# said                     VERB
# aloud                    ADV
# .                        PUNCT
# âI                     X
# must                     AUX
# be                       AUX
#
#                        SPACE
# getting                  VERB
# somewhere                ADV
# near                     ADP
# the                      DET
# centre                   NOUN
# of                       ADP
# the                      DET
# earth                    NOUN
# .                        PUNCT
# Let                      VERB
# me                       PRON
# see                      VERB
# :                        PUNCT
# that                     PRON
# would                    AUX
#
#                        SPACE
# be                       AUX
# four                     NUM
# thousand                 NUM
# miles                    NOUN
# down                     ADV
# ,                        PUNCT
# I                        PRON
# thinkââ              AUX
# (                        PUNCT
# for                      ADP
# ,                        PUNCT
# you                      PRON
# see                      VERB
# ,                        PUNCT
# Alice                    PROPN
# had                      AUX
# learnt                   VERB
#
#                        SPACE
# several                  ADJ
# things                   NOUN
# of                       ADP
# this                     DET
# sort                     NOUN
# in                       ADP
# her                      PRON
# lessons                  NOUN
# in                       ADP
# the                      DET
# schoolroom               NOUN
# ,                        PUNCT
# and                      CCONJ
#
#                        SPACE
# though                   SCONJ
# this                     PRON
# was                      AUX
# not                      PART
# a                        DET
# _                        NOUN
# very                     ADV
# _                        PRON
# good                     ADJ
# opportunity              NOUN
# for                      ADP
# showing                  VERB
# off                      ADP
# her                      PRON
#
#                        SPACE
# knowledge                NOUN
# ,                        PUNCT
# as                       SCONJ
# there                    PRON
# was                      VERB
# no                       DET
# one                      NOUN
# to                       PART
# listen                   VERB
# to                       ADP
# her                      PRON
# ,                        PUNCT
# still                    ADV
# it                       PRON
# was                      AUX
# good                     ADJ
#
#                        SPACE
# practice                 NOUN
# to                       PART
# say                      VERB
# it                       PRON
# over                     ADP
# )                        PUNCT
# ââyes                PROPN
# ,                        PUNCT
# thatâs                 VERB
# about                    ADP
# the                      DET
# right                    ADJ
# distanceâbut           NOUN
#
#                        SPACE
# then                     ADV
# I                        PRON
# wonder                   VERB
# what                     PRON
# Latitude                 PROPN
# or                       CCONJ
# Longitude                PROPN
# Iâve                   NUM
# got                      VERB
# to?â                   NOUN
# (                        PUNCT
# Alice                    PROPN
# had                      VERB
# no                       DET
#
#                        SPACE
# idea                     NOUN
# what                     PRON
# Latitude                 PROPN
# was                      AUX
# ,                        PUNCT
# or                       CCONJ
# Longitude                PROPN
# either                   ADV
# ,                        PUNCT
# but                      CCONJ
# thought                  VERB
# they                     PRON
# were                     AUX
# nice                     ADJ
#
#                        SPACE
# grand                    ADJ
# words                    NOUN
# to                       PART
# say                      VERB
# .                        PUNCT
# )                        PUNCT
#
#
#                      SPACE
# Presently                ADV
# she                      PRON
# began                    VERB
# again                    ADV
# .                        PUNCT
# âI                     PRON
# wonder                   NOUN
# if                       SCONJ
# I                        PRON
# shall                    AUX
# fall                     VERB
# right                    ADV
# _                        ADV
# through                  ADP
# _                        PROPN
#
#                        SPACE
# the                      DET
# earth                    NOUN
# !                        PUNCT
# How                      SCONJ
# funny                    ADJ
# itâll                  NOUN
# seem                     VERB
# to                       PART
# come                     VERB
# out                      ADP
# among                    ADP
# the                      DET
# people                   NOUN
# that                     PRON
# walk                     VERB
#
#                        SPACE
# with                     ADP
# their                    PRON
# heads                    NOUN
# downward                 ADV
# !                        PUNCT
# The                      DET
# Antipathies              PROPN
# ,                        PUNCT
# I                        PRON
# thinkââ              AUX
# (                        PUNCT
# she                      PRON
# was                      AUX
# rather                   ADV
#
#                        SPACE
# glad                     ADJ
# there                    PRON
# _                        NOUN
# was                      AUX
# _                        NOUN
# no                       DET
# one                      NOUN
# listening                VERB
# ,                        PUNCT
# this                     DET
# time                     NOUN
# ,                        PUNCT
# as                       SCONJ
# it                       PRON
# didnât                 NUM
# sound                    VERB
# at                       ADV
# all                      ADV
#
#                        SPACE
# the                      DET
# right                    ADJ
# word                     NOUN
# )                        PUNCT
# ââbut                PROPN
# I                        PRON
# shall                    AUX
# have                     VERB
# to                       PART
# ask                      VERB
# them                     PRON
# what                     PRON
# the                      DET
# name                     NOUN
# of                       ADP
# the                      DET
#
#                        SPACE
# country                  NOUN
# is                       AUX
# ,                        PUNCT
# you                      PRON
# know                     VERB
# .                        PUNCT
# Please                   INTJ
# ,                        PUNCT
# Maâam                  PROPN
# ,                        PUNCT
# is                       AUX
# this                     DET
# New                      PROPN
# Zealand                  PROPN
# or                       CCONJ
# Australia?â            PROPN
#
#                        SPACE
# (                        PUNCT
# and                      CCONJ
# she                      PRON
# tried                    VERB
# to                       PART
# curtsey                  VERB
# as                       SCONJ
# she                      PRON
# spokeâfancy            VERB
# _                        PUNCT
# curtseying               VERB
# _                        NOUN
# as                       SCONJ
# youâre                 PROPN
#
#                        SPACE
# falling                  VERB
# through                  ADP
# the                      DET
# air                      NOUN
# !                        PUNCT
# Do                       AUX
# you                      PRON
# think                    VERB
# you                      PRON
# could                    AUX
# manage                   VERB
# it                       PRON
# ?                        PUNCT
# )                        PUNCT
# âAnd                   NOUN
# what                     PRON
#
#                        SPACE
# an                       DET
# ignorant                 ADJ
# little                   ADJ
# girl                     NOUN
# sheâll                 NOUN
# think                    VERB
# me                       PRON
# for                      ADP
# asking                   VERB
# !                        PUNCT
# No                       INTJ
# ,                        PUNCT
# itâll                  NOUN
# never                    ADV
# do                       VERB
#
#                        SPACE
# to                       PART
# ask                      VERB
# :                        PUNCT
# perhaps                  ADV
# I                        PRON
# shall                    AUX
# see                      VERB
# it                       PRON
# written                  VERB
# up                       ADP
# somewhere.â            PROPN
#
#
#                      SPACE
# Down                     ADP
# ,                        PUNCT
# down                     ADV
# ,                        PUNCT
# down                     ADV
# .                        PUNCT
# There                    PRON
# was                      VERB
# nothing                  PRON
# else                     ADV
# to                       PART
# do                       VERB
# ,                        PUNCT
# so                       ADV
# Alice                    PROPN
# soon                     ADV
# began                    VERB
#
#                        SPACE
# talking                  VERB
# again                    ADV
# .                        PUNCT
# âDinahâll            NOUN
# miss                     VERB
# me                       PRON
# very                     ADV
# much                     ADV
# to                       ADP
# -                        PUNCT
# night                    NOUN
# ,                        PUNCT
# I                        PRON
# should                   AUX
# think!â                VERB
#
#                        SPACE
# (                        PUNCT
# Dinah                    PROPN
# was                      AUX
# the                      DET
# cat                      NOUN
# .                        PUNCT
# )                        PUNCT
# âI                     X
# hope                     VERB
# theyâll                PROPN
# remember                 VERB
# her                      PRON
# saucer                   NOUN
# of                       ADP
# milk                     NOUN
# at                       ADP
#
#                        SPACE
# tea                      NOUN
# -                        PUNCT
# time                     NOUN
# .                        PUNCT
# Dinah                    PROPN
# my                       PRON
# dear                     NOUN
# !                        PUNCT
# I                        PRON
# wish                     VERB
# you                      PRON
# were                     AUX
# down                     ADV
# here                     ADV
# with                     ADP
# me                       PRON
# !                        PUNCT
# There                    PRON
# are                      VERB
#
#                        SPACE
# no                       DET
# mice                     NOUN
# in                       ADP
# the                      DET
# air                      NOUN
# ,                        PUNCT
# Iâm                    NOUN
# afraid                   ADJ
# ,                        PUNCT
# but                      CCONJ
# you                      PRON
# might                    AUX
# catch                    VERB
# a                        DET
# bat                      NOUN
# ,                        PUNCT
# and                      CCONJ
# thatâs                 NOUN
#
#                        SPACE
# very                     ADV
# like                     ADP
# a                        DET
# mouse                    NOUN
# ,                        PUNCT
# you                      PRON
# know                     VERB
# .                        PUNCT
# But                      CCONJ
# do                       AUX
# cats                     NOUN
# eat                      VERB
# bats                     NOUN
# ,                        PUNCT
# I                        PRON
# wonder?â               PROPN
# And                      CCONJ
# here                     ADV
#
#                        SPACE
# Alice                    PROPN
# began                    VERB
# to                       PART
# get                      VERB
# rather                   ADV
# sleepy                   ADJ
# ,                        PUNCT
# and                      CCONJ
# went                     VERB
# on                       ADP
# saying                   VERB
# to                       ADP
# herself                  PRON
# ,                        PUNCT
# in                       ADP
# a                        DET
#
#                        SPACE
# dreamy                   ADJ
# sort                     NOUN
# of                       ADP
# way                      NOUN
# ,                        PUNCT
# âDo                    PROPN
# cats                     NOUN
# eat                      VERB
# bats                     NOUN
# ?                        PUNCT
# Do                       AUX
# cats                     NOUN
# eat                      VERB
# bats?â                 NOUN
# and                      CCONJ
#
#                        SPACE
# sometimes                ADV
# ,                        PUNCT
# âDo                    PROPN
# bats                     NOUN
# eat                      VERB
# cats?â                 NOUN
# for                      ADP
# ,                        PUNCT
# you                      PRON
# see                      VERB
# ,                        PUNCT
# as                       SCONJ
# she                      PRON
# couldnât               NUM
# answer                   NOUN
#
#                        SPACE
# either                   DET
# question                 NOUN
# ,                        PUNCT
# it                       PRON
# didnât                 NUM
# much                     ADV
# matter                   ADV
# which                    DET
# way                      NOUN
# she                      PRON
# put                      VERB
# it                       PRON
# .                        PUNCT
# She                      PRON
# felt                     VERB
#
#                        SPACE
# that                     SCONJ
# she                      PRON
# was                      AUX
# dozing                   VERB
# off                      ADP
# ,                        PUNCT
# and                      CCONJ
# had                      AUX
# just                     ADV
# begun                    VERB
# to                       PART
# dream                    VERB
# that                     SCONJ
# she                      PRON
# was                      AUX
#
#                        SPACE
# walking                  VERB
# hand                     NOUN
# in                       ADP
# hand                     NOUN
# with                     ADP
# Dinah                    PROPN
# ,                        PUNCT
# and                      CCONJ
# saying                   VERB
# to                       ADP
# her                      PRON
# very                     ADV
# earnestly                ADV
# ,                        PUNCT
#
#                        SPACE
# âNow                   PROPN
# ,                        PUNCT
# Dinah                    PROPN
# ,                        PUNCT
# tell                     VERB
# me                       PRON
# the                      DET
# truth                    NOUN
# :                        PUNCT
# did                      AUX
# you                      PRON
# ever                     ADV
# eat                      VERB
# a                        DET
# bat?â                  NOUN
# when                     SCONJ
# suddenly                 ADV
# ,                        PUNCT
#
#                        SPACE
# thump                    NOUN
# !                        PUNCT
# thump                    VERB
# !                        PUNCT
# down                     ADV
# she                      PRON
# came                     VERB
# upon                     SCONJ
# a                        DET
# heap                     NOUN
# of                       ADP
# sticks                   NOUN
# and                      CCONJ
# dry                      ADJ
# leaves                   NOUN
# ,                        PUNCT
# and                      CCONJ
#
#                        SPACE
# the                      DET
# fall                     NOUN
# was                      AUX
# over                     ADV
# .                        PUNCT
#
#
#                      SPACE
# Alice                    PROPN
# was                      AUX
# not                      PART
# a                        DET
# bit                      NOUN
# hurt                     ADJ
# ,                        PUNCT
# and                      CCONJ
# she                      PRON
# jumped                   VERB
# up                       ADP
# on                       ADP
# to                       ADP
# her                      PRON
# feet                     NOUN
# in                       ADP
# a                        DET
# moment                   NOUN
# :                        PUNCT
#
#                        SPACE
# she                      PRON
# looked                   VERB
# up                       ADP
# ,                        PUNCT
# but                      CCONJ
# it                       PRON
# was                      AUX
# all                      PRON
# dark                     ADJ
# overhead                 ADV
# ;                        PUNCT
# before                   SCONJ
# her                      PRON
# was                      AUX
# another                  DET
#
#                        SPACE
# long                     ADJ
# passage                  NOUN
# ,                        PUNCT
# and                      CCONJ
# the                      DET
# White                    PROPN
# Rabbit                   PROPN
# was                      AUX
# still                    ADV
# in                       ADP
# sight                    NOUN
# ,                        PUNCT
# hurrying                 VERB
# down                     ADP
#
#                        SPACE
# it                       PRON
# .                        PUNCT
# There                    PRON
# was                      VERB
# not                      PART
# a                        DET
# moment                   NOUN
# to                       PART
# be                       AUX
# lost                     VERB
# :                        PUNCT
# away                     ADV
# went                     VERB
# Alice                    PROPN
# like                     ADP
# the                      DET
# wind                     NOUN
# ,                        PUNCT
#
#                        SPACE
# and                      CCONJ
# was                      AUX
# just                     ADV
# in                       ADP
# time                     NOUN
# to                       PART
# hear                     VERB
# it                       PRON
# say                      VERB
# ,                        PUNCT
# as                       SCONJ
# it                       PRON
# turned                   VERB
# a                        DET
# ...
# ,                        PUNCT
# UT                       PROPN
# 84116                    NUM
# ,                        PUNCT
# (                        PUNCT
# 801                      NUM
# )                        PUNCT
# 596                      NUM
# -                        SYM
# 1887                     NUM
# .                        PUNCT
# Email                    NOUN
# contact                  NOUN
# links                    NOUN
# and                      CCONJ
# up                       ADV
#
#                        SPACE
# to                       ADP
# date                     NOUN
# contact                  NOUN
# information              NOUN
# can                      AUX
# be                       AUX
# found                    VERB
# at                       ADP
# the                      DET
# Foundation               PROPN
# 's                       PART
# website                  NOUN
#
#                        SPACE
# and                      CCONJ
# official                 ADJ
# page                     NOUN
# at                       ADP
# www.gutenberg.org/contactNOUN
#
#
#                      SPACE
# Section                  NOUN
# 4                        NUM
# .                        PUNCT
# Information              NOUN
# about                    ADP
# Donations                NOUN
# to                       ADP
# the                      DET
# Project                  PROPN
# Gutenberg                PROPN
#
#                        SPACE
# Literary                 PROPN
# Archive                  PROPN
# Foundation               PROPN
#
#
#                      SPACE
# Project                  PROPN
# Gutenberg                PROPN
# -                        PUNCT
# tm                       PROPN
# depends                  VERB
# upon                     SCONJ
# and                      CCONJ
# can                      AUX
# not                      PART
# survive                  VERB
# without                  ADP
#
#                        SPACE
# widespread               ADJ
# public                   ADJ
# support                  NOUN
# and                      CCONJ
# donations                NOUN
# to                       PART
# carry                    VERB
# out                      ADP
# its                      PRON
# mission                  NOUN
# of                       ADP
#
#                        SPACE
# increasing               VERB
# the                      DET
# number                   NOUN
# of                       ADP
# public                   ADJ
# domain                   NOUN
# and                      CCONJ
# licensed                 VERB
# works                    NOUN
# that                     PRON
# can                      AUX
# be                       AUX
#
#                        SPACE
# freely                   ADV
# distributed              VERB
# in                       ADP
# machine                  NOUN
# -                        PUNCT
# readable                 ADJ
# form                     NOUN
# accessible               ADJ
# by                       ADP
# the                      DET
# widest                   ADJ
#
#                        SPACE
# array                    NOUN
# of                       ADP
# equipment                NOUN
# including                VERB
# outdated                 ADJ
# equipment                NOUN
# .                        PUNCT
# Many                     ADJ
# small                    ADJ
# donations                NOUN
#
#                        SPACE
# (                        PUNCT
# $                        SYM
# 1                        NUM
# to                       PART
# $                        SYM
# 5,000                    NUM
# )                        PUNCT
# are                      AUX
# particularly             ADV
# important                ADJ
# to                       ADP
# maintaining              VERB
# tax                      NOUN
# exempt                   ADJ
#
#                        SPACE
# status                   NOUN
# with                     ADP
# the                      DET
# IRS                      PROPN
# .                        PUNCT
#
#
#                      SPACE
# The                      DET
# Foundation               PROPN
# is                       AUX
# committed                VERB
# to                       ADP
# complying                VERB
# with                     ADP
# the                      DET
# laws                     NOUN
# regulating               VERB
#
#                        SPACE
# charities                NOUN
# and                      CCONJ
# charitable               ADJ
# donations                NOUN
# in                       ADP
# all                      DET
# 50                       NUM
# states                   NOUN
# of                       ADP
# the                      DET
# United                   PROPN
#
#                        SPACE
# States                   PROPN
# .                        PUNCT
# Compliance               NOUN
# requirements             NOUN
# are                      AUX
# not                      PART
# uniform                  ADJ
# and                      CCONJ
# it                       PRON
# takes                    VERB
# a                        DET
#
#                        SPACE
# considerable             ADJ
# effort                   NOUN
# ,                        PUNCT
# much                     ADJ
# paperwork                NOUN
# and                      CCONJ
# many                     ADJ
# fees                     NOUN
# to                       PART
# meet                     VERB
# and                      CCONJ
# keep                     VERB
# up                       ADP
#
#                        SPACE
# with                     ADP
# these                    DET
# requirements             NOUN
# .                        PUNCT
# We                       PRON
# do                       AUX
# not                      PART
# solicit                  VERB
# donations                NOUN
# in                       ADP
# locations                NOUN
#
#                        SPACE
# where                    SCONJ
# we                       PRON
# have                     AUX
# not                      PART
# received                 VERB
# written                  VERB
# confirmation             NOUN
# of                       ADP
# compliance               NOUN
# .                        PUNCT
# To                       ADP
# SEND                     PROPN
#
#                        SPACE
# DONATIONS                NOUN
# or                       CCONJ
# determine                VERB
# the                      DET
# status                   NOUN
# of                       ADP
# compliance               NOUN
# for                      ADP
# any                      DET
# particular               ADJ
#
#                        SPACE
# state                    NOUN
# visit                    NOUN
# www.gutenberg.org/donate NOUN
#
#
#                      SPACE
# While                    SCONJ
# we                       PRON
# can                      AUX
# not                      PART
# and                      CCONJ
# do                       AUX
# not                      PART
# solicit                  VERB
# contributions            NOUN
# from                     ADP
# states                   NOUN
# where                    SCONJ
# we                       PRON
#
#                        SPACE
# have                     AUX
# not                      PART
# met                      VERB
# the                      DET
# solicitation             NOUN
# requirements             NOUN
# ,                        PUNCT
# we                       PRON
# know                     VERB
# of                       ADP
# no                       DET
# prohibition              NOUN
#
#                        SPACE
# against                  ADP
# accepting                VERB
# unsolicited              ADJ
# donations                NOUN
# from                     ADP
# donors                   NOUN
# in                       ADP
# such                     ADJ
# states                   NOUN
# who                      PRON
#
#                        SPACE
# approach                 VERB
# us                       PRON
# with                     ADP
# offers                   NOUN
# to                       PART
# donate                   VERB
# .                        PUNCT
#
#
#                      SPACE
# International            ADJ
# donations                NOUN
# are                      AUX
# gratefully               ADV
# accepted                 VERB
# ,                        PUNCT
# but                      CCONJ
# we                       PRON
# can                      AUX
# not                      PART
# make                     VERB
#
#                        SPACE
# any                      DET
# statements               NOUN
# concerning               VERB
# tax                      NOUN
# treatment                NOUN
# of                       ADP
# donations                NOUN
# received                 VERB
# from                     ADP
#
#                        SPACE
# outside                  ADP
# the                      DET
# United                   PROPN
# States                   PROPN
# .                        PUNCT
# U.S.                     PROPN
# laws                     NOUN
# alone                    ADV
# swamp                    VERB
# our                      PRON
# small                    ADJ
# staff                    NOUN
# .                        PUNCT
#
#
#                      SPACE
# Please                   INTJ
# check                    VERB
# the                      DET
# Project                  PROPN
# Gutenberg                PROPN
# web                      NOUN
# pages                    NOUN
# for                      ADP
# current                  ADJ
# donation                 NOUN
#
#                        SPACE
# methods                  NOUN
# and                      CCONJ
# addresses                NOUN
# .                        PUNCT
# Donations                NOUN
# are                      AUX
# accepted                 VERB
# in                       ADP
# a                        DET
# number                   NOUN
# of                       ADP
# other                    ADJ
#
#                        SPACE
# ways                     NOUN
# including                VERB
# checks                   NOUN
# ,                        PUNCT
# online                   ADJ
# payments                 NOUN
# and                      CCONJ
# credit                   NOUN
# card                     NOUN
# donations                NOUN
# .                        PUNCT
# To                       PART
#
#                        SPACE
# donate                   VERB
# ,                        PUNCT
# please                   INTJ
# visit                    VERB
# :                        PUNCT
# www.gutenberg.org/donate PROPN
#
#
#                      SPACE
# Section                  NOUN
# 5                        NUM
# .                        PUNCT
# General                  PROPN
# Information              PROPN
# About                    PROPN
# Project                  PROPN
# Gutenberg                PROPN
# -                        PUNCT
# tm                       PROPN
# electronic               ADJ
# works                    NOUN
#
#
#                      SPACE
# Professor                PROPN
# Michael                  PROPN
# S.                       PROPN
# Hart                     PROPN
# was                      AUX
# the                      DET
# originator               NOUN
# of                       ADP
# the                      DET
# Project                  PROPN
#
#                        SPACE
# Gutenberg                PROPN
# -                        PUNCT
# tm                       NOUN
# concept                  NOUN
# of                       ADP
# a                        DET
# library                  NOUN
# of                       ADP
# electronic               ADJ
# works                    NOUN
# that                     PRON
# could                    AUX
# be                       AUX
#
#                        SPACE
# freely                   ADV
# shared                   VERB
# with                     ADP
# anyone                   PRON
# .                        PUNCT
# For                      ADP
# forty                    NUM
# years                    NOUN
# ,                        PUNCT
# he                       PRON
# produced                 VERB
# and                      CCONJ
#
#                        SPACE
# distributed              VERB
# Project                  PROPN
# Gutenberg                PROPN
# -                        PUNCT
# tm                       PROPN
# eBooks                   PROPN
# with                     ADP
# only                     ADV
# a                        DET
# loose                    ADJ
# network                  NOUN
# of                       ADP
#
#                        SPACE
# volunteer                NOUN
# support                  NOUN
# .                        PUNCT
#
#
#                      SPACE
# Project                  PROPN
# Gutenberg                PROPN
# -                        PUNCT
# tm                       PROPN
# eBooks                   PROPN
# are                      AUX
# often                    ADV
# created                  VERB
# from                     ADP
# several                  ADJ
# printed                  VERB
#
#                        SPACE
# editions                 NOUN
# ,                        PUNCT
# all                      PRON
# of                       ADP
# which                    PRON
# are                      AUX
# confirmed                VERB
# as                       SCONJ
# not                      PART
# protected                VERB
# by                       ADP
# copyright                NOUN
# in                       ADP
#
#                        SPACE
# the                      DET
# U.S.                     PROPN
# unless                   SCONJ
# a                        DET
# copyright                NOUN
# notice                   NOUN
# is                       AUX
# included                 VERB
# .                        PUNCT
# Thus                     ADV
# ,                        PUNCT
# we                       PRON
# do                       AUX
# not                      PART
#
#                        SPACE
# necessarily              ADV
# keep                     VERB
# eBooks                   PROPN
# in                       ADP
# compliance               NOUN
# with                     ADP
# any                      DET
# particular               ADJ
# paper                    NOUN
#
#                        SPACE
# edition                  NOUN
# .                        PUNCT
#
#
#                      SPACE
# Most                     ADJ
# people                   NOUN
# start                    VERB
# at                       ADP
# our                      PRON
# website                  NOUN
# which                    PRON
# has                      VERB
# the                      DET
# main                     ADJ
# PG                       PROPN
# search                   NOUN
#
#                        SPACE
# facility                 NOUN
# :                        PUNCT
# www.gutenberg.org        NUM
#
#
#                      SPACE
# This                     DET
# website                  NOUN
# includes                 VERB
# information              NOUN
# about                    ADP
# Project                  PROPN
# Gutenberg                PROPN
# -                        PUNCT
# tm                       PROPN
# ,                        PUNCT
#
#                        SPACE
# including                VERB
# how                      SCONJ
# to                       PART
# make                     VERB
# donations                NOUN
# to                       ADP
# the                      DET
# Project                  PROPN
# Gutenberg                PROPN
# Literary                 PROPN
#
#                        SPACE
# Archive                  PROPN
# Foundation               PROPN
# ,                        PUNCT
# how                      SCONJ
# to                       PART
# help                     VERB
# produce                  VERB
# our                      PRON
# new                      ADJ
# eBooks                   PROPN
# ,                        PUNCT
# and                      CCONJ
# how                      SCONJ
# to                       PART
#
#                        SPACE
# subscribe                VERB
# to                       ADP
# our                      PRON
# email                    NOUN
# newsletter               NOUN
# to                       PART
# hear                     VERB
# about                    ADP
# new                      ADJ
# eBooks                   PROPN
# .                        PUNCT
#
#
#
#                    SPACE

# %%
from spacy.matcher import Matcher
from spacy.tokens import span

# %%
matcher = Matcher(nlp.vocab)

# %%
pattern_1 = [{'LOWER':'alice','POS':'PROPN'}]
matcher.add('Alice_PROPN',[pattern_1])

# %%
matches = matcher(doc)

# %%
# matches contains match_id,start & end position of the match 
matches[:10]
# Out:
# [(4167198918391854712, 323, 324),
#  (4167198918391854712, 384, 385),
#  (4167198918391854712, 472, 473),
#  (4167198918391854712, 567, 568),
#  (4167198918391854712, 646, 647),
#  (4167198918391854712, 690, 691),
#  (4167198918391854712, 884, 885),
#  (4167198918391854712, 1010, 1011),
#  (4167198918391854712, 1085, 1086),
#  (4167198918391854712, 1285, 1286)]

# %%
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(match_id,string_id,start,end,span.text)
# Out:
# 4167198918391854712 Alice_PROPN 323 324 Alice
# 4167198918391854712 Alice_PROPN 384 385 Alice
# 4167198918391854712 Alice_PROPN 472 473 Alice
# 4167198918391854712 Alice_PROPN 567 568 Alice
# 4167198918391854712 Alice_PROPN 646 647 Alice
# 4167198918391854712 Alice_PROPN 690 691 Alice
# 4167198918391854712 Alice_PROPN 884 885 Alice
# 4167198918391854712 Alice_PROPN 1010 1011 Alice
# 4167198918391854712 Alice_PROPN 1085 1086 Alice
# 4167198918391854712 Alice_PROPN 1285 1286 Alice
# 4167198918391854712 Alice_PROPN 1380 1381 Alice
# 4167198918391854712 Alice_PROPN 1519 1520 Alice
# 4167198918391854712 Alice_PROPN 1583 1584 Alice
# 4167198918391854712 Alice_PROPN 1682 1683 Alice
# 4167198918391854712 Alice_PROPN 1854 1855 Alice
# 4167198918391854712 Alice_PROPN 1948 1949 Alice
# 4167198918391854712 Alice_PROPN 2009 2010 Alice
# 4167198918391854712 Alice_PROPN 2095 2096 Alice
# 4167198918391854712 Alice_PROPN 2143 2144 Alice
# 4167198918391854712 Alice_PROPN 2311 2312 Alice
# 4167198918391854712 Alice_PROPN 2413 2414 Alice
# 4167198918391854712 Alice_PROPN 2509 2510 Alice
# 4167198918391854712 Alice_PROPN 2593 2594 Alice
# 4167198918391854712 Alice_PROPN 2700 2701 Alice
# 4167198918391854712 Alice_PROPN 2802 2803 Alice
# 4167198918391854712 Alice_PROPN 2881 2882 Alice
# 4167198918391854712 Alice_PROPN 2995 2996 Alice
# 4167198918391854712 Alice_PROPN 3107 3108 Alice
# 4167198918391854712 Alice_PROPN 3245 3246 Alice
# 4167198918391854712 Alice_PROPN 3402 3403 Alice
# 4167198918391854712 Alice_PROPN 3461 3462 Alice
# 4167198918391854712 Alice_PROPN 3626 3627 Alice
# 4167198918391854712 Alice_PROPN 3697 3698 Alice
# 4167198918391854712 Alice_PROPN 4153 4154 Alice
# 4167198918391854712 Alice_PROPN 4297 4298 Alice
# 4167198918391854712 Alice_PROPN 4471 4472 Alice
# 4167198918391854712 Alice_PROPN 4636 4637 Alice
# 4167198918391854712 Alice_PROPN 4740 4741 Alice
# 4167198918391854712 Alice_PROPN 4880 4881 Alice
# 4167198918391854712 Alice_PROPN 4953 4954 Alice
# 4167198918391854712 Alice_PROPN 5036 5037 Alice
# 4167198918391854712 Alice_PROPN 5063 5064 Alice
# 4167198918391854712 Alice_PROPN 5129 5130 Alice
# 4167198918391854712 Alice_PROPN 5185 5186 Alice
# 4167198918391854712 Alice_PROPN 5236 5237 Alice
# 4167198918391854712 Alice_PROPN 5297 5298 Alice
# 4167198918391854712 Alice_PROPN 5393 5394 Alice
# 4167198918391854712 Alice_PROPN 5420 5421 Alice
# 4167198918391854712 Alice_PROPN 5528 5529 Alice
# 4167198918391854712 Alice_PROPN 5629 5630 Alice
# 4167198918391854712 Alice_PROPN 5718 5719 Alice
# 4167198918391854712 Alice_PROPN 5820 5821 Alice
# 4167198918391854712 Alice_PROPN 5877 5878 Alice
# 4167198918391854712 Alice_PROPN 5972 5973 Alice
# 4167198918391854712 Alice_PROPN 6293 6294 Alice
# 4167198918391854712 Alice_PROPN 6306 6307 Alice
# 4167198918391854712 Alice_PROPN 6450 6451 Alice
# 4167198918391854712 Alice_PROPN 6778 6779 Alice
# 4167198918391854712 Alice_PROPN 6806 6807 Alice
# 4167198918391854712 Alice_PROPN 6909 6910 Alice
# 4167198918391854712 Alice_PROPN 6918 6919 Alice
# 4167198918391854712 Alice_PROPN 6977 6978 Alice
# 4167198918391854712 Alice_PROPN 7118 7119 Alice
# 4167198918391854712 Alice_PROPN 7162 7163 Alice
# 4167198918391854712 Alice_PROPN 7181 7182 Alice
# 4167198918391854712 Alice_PROPN 7341 7342 Alice
# 4167198918391854712 Alice_PROPN 7358 7359 Alice
# 4167198918391854712 Alice_PROPN 7391 7392 Alice
# 4167198918391854712 Alice_PROPN 7451 7452 Alice
# 4167198918391854712 Alice_PROPN 7478 7479 Alice
# 4167198918391854712 Alice_PROPN 7605 7606 Alice
# 4167198918391854712 Alice_PROPN 7639 7640 Alice
# 4167198918391854712 Alice_PROPN 7788 7789 Alice
# 4167198918391854712 Alice_PROPN 7853 7854 Alice
# 4167198918391854712 Alice_PROPN 8007 8008 Alice
# 4167198918391854712 Alice_PROPN 8086 8087 Alice
# 4167198918391854712 Alice_PROPN 8141 8142 Alice
# 4167198918391854712 Alice_PROPN 8302 8303 Alice
# 4167198918391854712 Alice_PROPN 8339 8340 Alice
# 4167198918391854712 Alice_PROPN 8378 8379 Alice
# 4167198918391854712 Alice_PROPN 8777 8778 Alice
# 4167198918391854712 Alice_PROPN 8843 8844 Alice
# 4167198918391854712 Alice_PROPN 8990 8991 Alice
# 4167198918391854712 Alice_PROPN 9144 9145 Alice
# 4167198918391854712 Alice_PROPN 9235 9236 Alice
# 4167198918391854712 Alice_PROPN 9258 9259 Alice
# 4167198918391854712 Alice_PROPN 9504 9505 Alice
# 4167198918391854712 Alice_PROPN 9590 9591 Alice
# 4167198918391854712 Alice_PROPN 9814 9815 Alice
# 4167198918391854712 Alice_PROPN 10010 10011 Alice
# 4167198918391854712 Alice_PROPN 10087 10088 Alice
# 4167198918391854712 Alice_PROPN 10115 10116 Alice
# 4167198918391854712 Alice_PROPN 10157 10158 Alice
# 4167198918391854712 Alice_PROPN 10178 10179 Alice
# 4167198918391854712 Alice_PROPN 10248 10249 Alice
# 4167198918391854712 Alice_PROPN 10418 10419 Alice
# 4167198918391854712 Alice_PROPN 10457 10458 Alice
# 4167198918391854712 Alice_PROPN 10602 10603 Alice
# 4167198918391854712 Alice_PROPN 10718 10719 Alice
# 4167198918391854712 Alice_PROPN 10770 10771 Alice
# 4167198918391854712 Alice_PROPN 10878 10879 Alice
# 4167198918391854712 Alice_PROPN 10931 10932 Alice
# 4167198918391854712 Alice_PROPN 11032 11033 Alice
# 4167198918391854712 Alice_PROPN 11202 11203 Alice
# 4167198918391854712 Alice_PROPN 11257 11258 Alice
# 4167198918391854712 Alice_PROPN 11332 11333 Alice
# 4167198918391854712 Alice_PROPN 11363 11364 Alice
# 4167198918391854712 Alice_PROPN 11414 11415 Alice
# 4167198918391854712 Alice_PROPN 11475 11476 Alice
# 4167198918391854712 Alice_PROPN 11516 11517 Alice
# 4167198918391854712 Alice_PROPN 11575 11576 Alice
# 4167198918391854712 Alice_PROPN 11629 11630 Alice
# 4167198918391854712 Alice_PROPN 11651 11652 Alice
# 4167198918391854712 Alice_PROPN 11673 11674 Alice
# 4167198918391854712 Alice_PROPN 11752 11753 Alice
# 4167198918391854712 Alice_PROPN 11804 11805 Alice
# 4167198918391854712 Alice_PROPN 11826 11827 Alice
# 4167198918391854712 Alice_PROPN 12214 12215 Alice
# 4167198918391854712 Alice_PROPN 12281 12282 Alice
# 4167198918391854712 Alice_PROPN 12309 12310 Alice
# 4167198918391854712 Alice_PROPN 12369 12370 Alice
# 4167198918391854712 Alice_PROPN 12418 12419 Alice
# 4167198918391854712 Alice_PROPN 12472 12473 Alice
# 4167198918391854712 Alice_PROPN 12564 12565 Alice
# 4167198918391854712 Alice_PROPN 12600 12601 Alice
# 4167198918391854712 Alice_PROPN 12855 12856 Alice
# 4167198918391854712 Alice_PROPN 12934 12935 Alice
# 4167198918391854712 Alice_PROPN 13129 13130 Alice
# 4167198918391854712 Alice_PROPN 13186 13187 Alice
# 4167198918391854712 Alice_PROPN 13228 13229 Alice
# 4167198918391854712 Alice_PROPN 13308 13309 Alice
# 4167198918391854712 Alice_PROPN 13388 13389 Alice
# 4167198918391854712 Alice_PROPN 13422 13423 Alice
# 4167198918391854712 Alice_PROPN 13525 13526 Alice
# 4167198918391854712 Alice_PROPN 13588 13589 Alice
# 4167198918391854712 Alice_PROPN 13651 13652 Alice
# 4167198918391854712 Alice_PROPN 13709 13710 Alice
# 4167198918391854712 Alice_PROPN 13949 13950 Alice
# 4167198918391854712 Alice_PROPN 14113 14114 Alice
# 4167198918391854712 Alice_PROPN 14256 14257 Alice
# 4167198918391854712 Alice_PROPN 14315 14316 Alice
# 4167198918391854712 Alice_PROPN 14429 14430 Alice
# 4167198918391854712 Alice_PROPN 14508 14509 Alice
# 4167198918391854712 Alice_PROPN 14652 14653 Alice
# 4167198918391854712 Alice_PROPN 14689 14690 Alice
# 4167198918391854712 Alice_PROPN 14770 14771 Alice
# 4167198918391854712 Alice_PROPN 14799 14800 Alice
# 4167198918391854712 Alice_PROPN 14887 14888 Alice
# 4167198918391854712 Alice_PROPN 14981 14982 Alice
# 4167198918391854712 Alice_PROPN 15039 15040 Alice
# 4167198918391854712 Alice_PROPN 15123 15124 Alice
# 4167198918391854712 Alice_PROPN 15155 15156 Alice
# 4167198918391854712 Alice_PROPN 15292 15293 Alice
# 4167198918391854712 Alice_PROPN 15374 15375 Alice
# 4167198918391854712 Alice_PROPN 15440 15441 Alice
# 4167198918391854712 Alice_PROPN 15636 15637 Alice
# 4167198918391854712 Alice_PROPN 15698 15699 Alice
# 4167198918391854712 Alice_PROPN 15755 15756 Alice
# 4167198918391854712 Alice_PROPN 15795 15796 Alice
# 4167198918391854712 Alice_PROPN 15925 15926 Alice
# 4167198918391854712 Alice_PROPN 15980 15981 Alice
# 4167198918391854712 Alice_PROPN 16000 16001 Alice
# 4167198918391854712 Alice_PROPN 16058 16059 Alice
# 4167198918391854712 Alice_PROPN 16122 16123 Alice
# 4167198918391854712 Alice_PROPN 16168 16169 Alice
# 4167198918391854712 Alice_PROPN 16381 16382 Alice
# 4167198918391854712 Alice_PROPN 16465 16466 Alice
# 4167198918391854712 Alice_PROPN 16514 16515 Alice
# 4167198918391854712 Alice_PROPN 16539 16540 Alice
# 4167198918391854712 Alice_PROPN 16567 16568 Alice
# 4167198918391854712 Alice_PROPN 16652 16653 Alice
# 4167198918391854712 Alice_PROPN 16687 16688 Alice
# 4167198918391854712 Alice_PROPN 16706 16707 Alice
# 4167198918391854712 Alice_PROPN 16754 16755 Alice
# 4167198918391854712 Alice_PROPN 16819 16820 Alice
# 4167198918391854712 Alice_PROPN 16854 16855 Alice
# 4167198918391854712 Alice_PROPN 16878 16879 Alice
# 4167198918391854712 Alice_PROPN 16945 16946 Alice
# 4167198918391854712 Alice_PROPN 16978 16979 Alice
# 4167198918391854712 Alice_PROPN 17108 17109 Alice
# 4167198918391854712 Alice_PROPN 17187 17188 Alice
# 4167198918391854712 Alice_PROPN 17412 17413 Alice
# 4167198918391854712 Alice_PROPN 17460 17461 Alice
# 4167198918391854712 Alice_PROPN 17470 17471 Alice
# 4167198918391854712 Alice_PROPN 17507 17508 Alice
# 4167198918391854712 Alice_PROPN 17559 17560 Alice
# 4167198918391854712 Alice_PROPN 17596 17597 Alice
# 4167198918391854712 Alice_PROPN 17625 17626 Alice
# 4167198918391854712 Alice_PROPN 17652 17653 Alice
# 4167198918391854712 Alice_PROPN 17702 17703 Alice
# 4167198918391854712 Alice_PROPN 17749 17750 Alice
# 4167198918391854712 Alice_PROPN 17772 17773 Alice
# 4167198918391854712 Alice_PROPN 17930 17931 Alice
# 4167198918391854712 Alice_PROPN 17973 17974 Alice
# 4167198918391854712 Alice_PROPN 18009 18010 Alice
# 4167198918391854712 Alice_PROPN 18148 18149 Alice
# 4167198918391854712 Alice_PROPN 18209 18210 Alice
# 4167198918391854712 Alice_PROPN 18243 18244 Alice
# 4167198918391854712 Alice_PROPN 18354 18355 Alice
# 4167198918391854712 Alice_PROPN 18367 18368 Alice
# 4167198918391854712 Alice_PROPN 18396 18397 Alice
# 4167198918391854712 Alice_PROPN 18466 18467 Alice
# 4167198918391854712 Alice_PROPN 18497 18498 Alice
# 4167198918391854712 Alice_PROPN 18634 18635 Alice
# 4167198918391854712 Alice_PROPN 18685 18686 Alice
# 4167198918391854712 Alice_PROPN 18778 18779 Alice
# 4167198918391854712 Alice_PROPN 18898 18899 Alice
# 4167198918391854712 Alice_PROPN 18997 18998 Alice
# 4167198918391854712 Alice_PROPN 19025 19026 Alice
# 4167198918391854712 Alice_PROPN 19072 19073 Alice
# 4167198918391854712 Alice_PROPN 19152 19153 Alice
# 4167198918391854712 Alice_PROPN 19224 19225 Alice
# 4167198918391854712 Alice_PROPN 19270 19271 Alice
# 4167198918391854712 Alice_PROPN 19293 19294 Alice
# 4167198918391854712 Alice_PROPN 19347 19348 Alice
# 4167198918391854712 Alice_PROPN 19359 19360 Alice
# 4167198918391854712 Alice_PROPN 19405 19406 Alice
# 4167198918391854712 Alice_PROPN 19419 19420 Alice
# 4167198918391854712 Alice_PROPN 19498 19499 Alice
# 4167198918391854712 Alice_PROPN 19543 19544 Alice
# 4167198918391854712 Alice_PROPN 19600 19601 Alice
# 4167198918391854712 Alice_PROPN 19666 19667 Alice
# 4167198918391854712 Alice_PROPN 19694 19695 Alice
# 4167198918391854712 Alice_PROPN 19721 19722 Alice
# 4167198918391854712 Alice_PROPN 19796 19797 Alice
# 4167198918391854712 Alice_PROPN 19830 19831 Alice
# 4167198918391854712 Alice_PROPN 19893 19894 Alice
# 4167198918391854712 Alice_PROPN 19904 19905 Alice
# 4167198918391854712 Alice_PROPN 20006 20007 Alice
# 4167198918391854712 Alice_PROPN 20035 20036 Alice
# 4167198918391854712 Alice_PROPN 20121 20122 Alice
# 4167198918391854712 Alice_PROPN 20364 20365 Alice
# 4167198918391854712 Alice_PROPN 20553 20554 Alice
# 4167198918391854712 Alice_PROPN 20590 20591 Alice
# 4167198918391854712 Alice_PROPN 20744 20745 Alice
# 4167198918391854712 Alice_PROPN 20863 20864 Alice
# 4167198918391854712 Alice_PROPN 20931 20932 Alice
# 4167198918391854712 Alice_PROPN 21021 21022 Alice
# 4167198918391854712 Alice_PROPN 21074 21075 Alice
# 4167198918391854712 Alice_PROPN 21089 21090 Alice
# 4167198918391854712 Alice_PROPN 21098 21099 Alice
# 4167198918391854712 Alice_PROPN 21216 21217 Alice
# 4167198918391854712 Alice_PROPN 21264 21265 Alice
# 4167198918391854712 Alice_PROPN 21485 21486 Alice
# 4167198918391854712 Alice_PROPN 21495 21496 Alice
# 4167198918391854712 Alice_PROPN 21585 21586 Alice
# 4167198918391854712 Alice_PROPN 21600 21601 Alice
# 4167198918391854712 Alice_PROPN 21612 21613 Alice
# 4167198918391854712 Alice_PROPN 21662 21663 Alice
# 4167198918391854712 Alice_PROPN 21720 21721 Alice
# 4167198918391854712 Alice_PROPN 21741 21742 Alice
# 4167198918391854712 Alice_PROPN 21767 21768 Alice
# 4167198918391854712 Alice_PROPN 21856 21857 Alice
# 4167198918391854712 Alice_PROPN 21919 21920 Alice
# 4167198918391854712 Alice_PROPN 22100 22101 Alice
# 4167198918391854712 Alice_PROPN 22180 22181 Alice
# 4167198918391854712 Alice_PROPN 22356 22357 Alice
# 4167198918391854712 Alice_PROPN 22402 22403 Alice
# 4167198918391854712 Alice_PROPN 22463 22464 Alice
# 4167198918391854712 Alice_PROPN 22586 22587 Alice
# 4167198918391854712 Alice_PROPN 22647 22648 Alice
# 4167198918391854712 Alice_PROPN 22671 22672 Alice
# 4167198918391854712 Alice_PROPN 22737 22738 Alice
# 4167198918391854712 Alice_PROPN 22753 22754 Alice
# 4167198918391854712 Alice_PROPN 22858 22859 Alice
# 4167198918391854712 Alice_PROPN 22970 22971 Alice
# 4167198918391854712 Alice_PROPN 23005 23006 Alice
# 4167198918391854712 Alice_PROPN 23062 23063 Alice
# 4167198918391854712 Alice_PROPN 23173 23174 Alice
# 4167198918391854712 Alice_PROPN 23348 23349 Alice
# 4167198918391854712 Alice_PROPN 23507 23508 Alice
# 4167198918391854712 Alice_PROPN 23741 23742 Alice
# 4167198918391854712 Alice_PROPN 23783 23784 Alice
# 4167198918391854712 Alice_PROPN 23913 23914 Alice
# 4167198918391854712 Alice_PROPN 23989 23990 Alice
# 4167198918391854712 Alice_PROPN 24046 24047 Alice
# 4167198918391854712 Alice_PROPN 24097 24098 Alice
# 4167198918391854712 Alice_PROPN 24130 24131 Alice
# 4167198918391854712 Alice_PROPN 24152 24153 Alice
# 4167198918391854712 Alice_PROPN 24190 24191 Alice
# 4167198918391854712 Alice_PROPN 24298 24299 Alice
# 4167198918391854712 Alice_PROPN 24360 24361 Alice
# 4167198918391854712 Alice_PROPN 24392 24393 Alice
# 4167198918391854712 Alice_PROPN 24442 24443 Alice
# 4167198918391854712 Alice_PROPN 24518 24519 Alice
# 4167198918391854712 Alice_PROPN 24632 24633 Alice
# 4167198918391854712 Alice_PROPN 24635 24636 Alice
# 4167198918391854712 Alice_PROPN 24798 24799 Alice
# 4167198918391854712 Alice_PROPN 24825 24826 Alice
# 4167198918391854712 Alice_PROPN 24840 24841 Alice
# 4167198918391854712 Alice_PROPN 24880 24881 Alice
# 4167198918391854712 Alice_PROPN 24909 24910 Alice
# 4167198918391854712 Alice_PROPN 25039 25040 Alice
# 4167198918391854712 Alice_PROPN 25046 25047 Alice
# 4167198918391854712 Alice_PROPN 25127 25128 Alice
# 4167198918391854712 Alice_PROPN 25137 25138 Alice
# 4167198918391854712 Alice_PROPN 25175 25176 Alice
# 4167198918391854712 Alice_PROPN 25233 25234 Alice
# 4167198918391854712 Alice_PROPN 25389 25390 Alice
# 4167198918391854712 Alice_PROPN 25473 25474 Alice
# 4167198918391854712 Alice_PROPN 25579 25580 Alice
# 4167198918391854712 Alice_PROPN 25637 25638 Alice
# 4167198918391854712 Alice_PROPN 25703 25704 Alice
# 4167198918391854712 Alice_PROPN 25724 25725 Alice
# 4167198918391854712 Alice_PROPN 25765 25766 Alice
# 4167198918391854712 Alice_PROPN 25792 25793 Alice
# 4167198918391854712 Alice_PROPN 25811 25812 Alice
# 4167198918391854712 Alice_PROPN 25870 25871 Alice
# 4167198918391854712 Alice_PROPN 25907 25908 Alice
# 4167198918391854712 Alice_PROPN 25951 25952 Alice
# 4167198918391854712 Alice_PROPN 25994 25995 Alice
# 4167198918391854712 Alice_PROPN 26027 26028 Alice
# 4167198918391854712 Alice_PROPN 26132 26133 Alice
# 4167198918391854712 Alice_PROPN 26259 26260 Alice
# 4167198918391854712 Alice_PROPN 26297 26298 Alice
# 4167198918391854712 Alice_PROPN 26328 26329 Alice
# 4167198918391854712 Alice_PROPN 26376 26377 Alice
# 4167198918391854712 Alice_PROPN 26434 26435 Alice
# 4167198918391854712 Alice_PROPN 26539 26540 Alice
# 4167198918391854712 Alice_PROPN 26580 26581 Alice
# 4167198918391854712 Alice_PROPN 26835 26836 Alice
# 4167198918391854712 Alice_PROPN 26848 26849 Alice
# 4167198918391854712 Alice_PROPN 26873 26874 Alice
# 4167198918391854712 Alice_PROPN 26930 26931 Alice
# 4167198918391854712 Alice_PROPN 27267 27268 Alice
# 4167198918391854712 Alice_PROPN 27318 27319 Alice
# 4167198918391854712 Alice_PROPN 27369 27370 Alice
# 4167198918391854712 Alice_PROPN 27518 27519 Alice
# 4167198918391854712 Alice_PROPN 27570 27571 Alice
# 4167198918391854712 Alice_PROPN 27587 27588 Alice
# 4167198918391854712 Alice_PROPN 27630 27631 Alice
# 4167198918391854712 Alice_PROPN 27689 27690 Alice
# 4167198918391854712 Alice_PROPN 27730 27731 Alice
# 4167198918391854712 Alice_PROPN 27794 27795 Alice
# 4167198918391854712 Alice_PROPN 27846 27847 Alice
# 4167198918391854712 Alice_PROPN 27894 27895 Alice
# 4167198918391854712 Alice_PROPN 27954 27955 Alice
# 4167198918391854712 Alice_PROPN 28132 28133 Alice
# 4167198918391854712 Alice_PROPN 28165 28166 Alice
# 4167198918391854712 Alice_PROPN 28373 28374 Alice
# 4167198918391854712 Alice_PROPN 28469 28470 Alice
# 4167198918391854712 Alice_PROPN 28512 28513 Alice
# 4167198918391854712 Alice_PROPN 28701 28702 Alice
# 4167198918391854712 Alice_PROPN 28757 28758 Alice
# 4167198918391854712 Alice_PROPN 28982 28983 Alice
# 4167198918391854712 Alice_PROPN 29006 29007 Alice
# 4167198918391854712 Alice_PROPN 29186 29187 Alice
# 4167198918391854712 Alice_PROPN 29238 29239 Alice
# 4167198918391854712 Alice_PROPN 29358 29359 Alice
# 4167198918391854712 Alice_PROPN 29475 29476 Alice
# 4167198918391854712 Alice_PROPN 29525 29526 Alice
# 4167198918391854712 Alice_PROPN 29573 29574 Alice
# 4167198918391854712 Alice_PROPN 29647 29648 Alice
# 4167198918391854712 Alice_PROPN 29664 29665 Alice
# 4167198918391854712 Alice_PROPN 30259 30260 Alice
# 4167198918391854712 Alice_PROPN 30357 30358 Alice
# 4167198918391854712 Alice_PROPN 30382 30383 Alice
# 4167198918391854712 Alice_PROPN 30921 30922 Alice
# 4167198918391854712 Alice_PROPN 31045 31046 Alice
# 4167198918391854712 Alice_PROPN 31178 31179 Alice
# 4167198918391854712 Alice_PROPN 31451 31452 Alice
# 4167198918391854712 Alice_PROPN 31526 31527 Alice
# 4167198918391854712 Alice_PROPN 31725 31726 Alice
# 4167198918391854712 Alice_PROPN 31732 31733 Alice
# 4167198918391854712 Alice_PROPN 31920 31921 Alice
# 4167198918391854712 Alice_PROPN 31927 31928 Alice
# 4167198918391854712 Alice_PROPN 31943 31944 Alice
# 4167198918391854712 Alice_PROPN 32064 32065 Alice
# 4167198918391854712 Alice_PROPN 32148 32149 Alice
# 4167198918391854712 Alice_PROPN 32160 32161 Alice
# 4167198918391854712 Alice_PROPN 32195 32196 Alice
# 4167198918391854712 Alice_PROPN 32236 32237 Alice
# 4167198918391854712 Alice_PROPN 32610 32611 Alice
# 4167198918391854712 Alice_PROPN 32922 32923 Alice
# 4167198918391854712 Alice_PROPN 33202 33203 Alice
# 4167198918391854712 Alice_PROPN 33411 33412 Alice
# 4167198918391854712 Alice_PROPN 33437 33438 Alice
# 4167198918391854712 Alice_PROPN 33464 33465 Alice
# 4167198918391854712 Alice_PROPN 33572 33573 Alice
# 4167198918391854712 Alice_PROPN 33597 33598 Alice
# 4167198918391854712 Alice_PROPN 33670 33671 Alice
# 4167198918391854712 Alice_PROPN 33725 33726 Alice
# 4167198918391854712 Alice_PROPN 33757 33758 Alice

# %%
matcher_2 = Matcher(nlp.vocab)
pattern_2 = [{"LOWER": 'alice', "POS":"PROPN"}, {'POS': {"NOT_IN": ['AUX']}}]
matcher_2.add('Alice_PROPN',[pattern_2])
matches_2 = matcher_2(doc)

for match_id, start, end in matches_2:
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(match_id,string_id,start,end,span.text)
# Out:
# 4167198918391854712 Alice_PROPN 384 386 Alice
#
# 4167198918391854712 Alice_PROPN 472 474 Alice think
# 4167198918391854712 Alice_PROPN 567 569 Alice started
# 4167198918391854712 Alice_PROPN 646 648 Alice after
# 4167198918391854712 Alice_PROPN 690 692 Alice had
# 4167198918391854712 Alice_PROPN 884 886 Alice to
# 4167198918391854712 Alice_PROPN 1085 1087 Alice had
# 4167198918391854712 Alice_PROPN 1285 1287 Alice soon
# 4167198918391854712 Alice_PROPN 1380 1382 Alice began
# 4167198918391854712 Alice_PROPN 1583 1585 Alice like
# 4167198918391854712 Alice_PROPN 1854 1856 Alice opened
# 4167198918391854712 Alice_PROPN 1948 1950 Alice,
# 4167198918391854712 Alice_PROPN 2095 2097 Alice,
# 4167198918391854712 Alice_PROPN 2311 2313 Alice ventured
# 4167198918391854712 Alice_PROPN 2413 2415 Alice;
# 4167198918391854712 Alice_PROPN 2509 2511 Alice to
# 4167198918391854712 Alice_PROPN 2593 2595 Alice!
# 4167198918391854712 Alice_PROPN 2700 2702 Alice to
# 4167198918391854712 Alice_PROPN 2802 2804 Alice,
# 4167198918391854712 Alice_PROPN 2881 2883 Alice,
# 4167198918391854712 Alice_PROPN 2995 2997 Alice
#
# 4167198918391854712 Alice_PROPN 3107 3109 Alice (
# 4167198918391854712 Alice_PROPN 3245 3247 Alice,
# 4167198918391854712 Alice_PROPN 3402 3404 Alice!
# 4167198918391854712 Alice_PROPN 3461 3463 Alice,
# 4167198918391854712 Alice_PROPN 3626 3628 Alice felt
# 4167198918391854712 Alice_PROPN 3697 3699 Alice took
# 4167198918391854712 Alice_PROPN 4153 4155 Alice,
# 4167198918391854712 Alice_PROPN 4297 4299 Alice,
# 4167198918391854712 Alice_PROPN 4471 4473 Alice,
# 4167198918391854712 Alice_PROPN 4740 4742 Alice,
# 4167198918391854712 Alice_PROPN 4880 4882 Alice,
# 4167198918391854712 Alice_PROPN 4953 4955 Alice thought
# 4167198918391854712 Alice_PROPN 5036 5038 Alice;
# 4167198918391854712 Alice_PROPN 5063 5065 Alice had
# 4167198918391854712 Alice_PROPN 5129 5131 Alice hastily
# 4167198918391854712 Alice_PROPN 5185 5187 Alice in
# 4167198918391854712 Alice_PROPN 5236 5238 Alice went
# 4167198918391854712 Alice_PROPN 5297 5299 Alice again
# 4167198918391854712 Alice_PROPN 5393 5395 Alice,
# 4167198918391854712 Alice_PROPN 5420 5422 Alice went
# 4167198918391854712 Alice_PROPN 5528 5530 Alice in
# 4167198918391854712 Alice_PROPN 5629 5631 Alice thought
# 4167198918391854712 Alice_PROPN 5718 5720 Alice
#
# 4167198918391854712 Alice_PROPN 5820 5822 Alice to
# 4167198918391854712 Alice_PROPN 5972 5974 Alice kept
# 4167198918391854712 Alice_PROPN 6293 6295 Alice as
# 4167198918391854712 Alice_PROPN 6306 6308 Alice in
# 4167198918391854712 Alice_PROPN 6450 6452 Alice;
# 4167198918391854712 Alice_PROPN 6778 6780 Alice with
# 4167198918391854712 Alice_PROPN 6806 6808 Alice had
# 4167198918391854712 Alice_PROPN 6909 6911 Alice.
# 4167198918391854712 Alice_PROPN 6918 6920 Alice sadly
# 4167198918391854712 Alice_PROPN 6977 6979 Alice thought
# 4167198918391854712 Alice_PROPN 7118 7120 Alice,
# 4167198918391854712 Alice_PROPN 7162 7164 Alice,
# 4167198918391854712 Alice_PROPN 7181 7183 Alice,
# 4167198918391854712 Alice_PROPN 7341 7343 Alice severely
# 4167198918391854712 Alice_PROPN 7358 7360 Alice very
# 4167198918391854712 Alice_PROPN 7391 7393 Alice,
# 4167198918391854712 Alice_PROPN 7451 7453 Alice.
# 4167198918391854712 Alice_PROPN 7478 7480 Alice called
# 4167198918391854712 Alice_PROPN 7605 7607 Alice aloud
# 4167198918391854712 Alice_PROPN 7639 7641 Alice replied
# 4167198918391854712 Alice_PROPN 7853 7855 Alice began
# 4167198918391854712 Alice_PROPN 8007 8009 Alice guessed
# 4167198918391854712 Alice_PROPN 8086 8088 Alice,
# 4167198918391854712 Alice_PROPN 8302 8304 Alice said
# 4167198918391854712 Alice_PROPN 8339 8341 Alice!
# 4167198918391854712 Alice_PROPN 8378 8380 Alice went
# 4167198918391854712 Alice_PROPN 8777 8779 Alice,
# 4167198918391854712 Alice_PROPN 8843 8845 Alice,
# 4167198918391854712 Alice_PROPN 8990 8992 Alice,
# 4167198918391854712 Alice_PROPN 9144 9146 Alice knew
# 4167198918391854712 Alice_PROPN 9235 9237 Alice heard
# 4167198918391854712 Alice_PROPN 9258 9260 Alice,
# 4167198918391854712 Alice_PROPN 9590 9592 Alice.
# 4167198918391854712 Alice_PROPN 9814 9816 Alice to
# 4167198918391854712 Alice_PROPN 10010 10012 Alice,
# 4167198918391854712 Alice_PROPN 10087 10089 Alice
#
# 4167198918391854712 Alice_PROPN 10115 10117 Alice thought
# 4167198918391854712 Alice_PROPN 10157 10159 Alice heard
# 4167198918391854712 Alice_PROPN 10178 10180 Alice;
# 4167198918391854712 Alice_PROPN 10248 10250 Alice noticed
# 4167198918391854712 Alice_PROPN 10418 10420 Alice the
# 4167198918391854712 Alice_PROPN 10457 10459 Alice to
# 4167198918391854712 Alice_PROPN 10602 10604 Alice,
# 4167198918391854712 Alice_PROPN 10718 10720 Alice dodged
# 4167198918391854712 Alice_PROPN 10770 10772 Alice,
# 4167198918391854712 Alice_PROPN 10878 10880 Alice a
# 4167198918391854712 Alice_PROPN 10931 10933 Alice,
# 4167198918391854712 Alice_PROPN 11032 11034 Alice looked
# 4167198918391854712 Alice_PROPN 11202 11204 Alice looked
# 4167198918391854712 Alice_PROPN 11257 11259 Alice replied
# 4167198918391854712 Alice_PROPN 11332 11334 Alice,
# 4167198918391854712 Alice_PROPN 11363 11365 Alice replied
# 4167198918391854712 Alice_PROPN 11414 11416 Alice;
# 4167198918391854712 Alice_PROPN 11475 11477 Alice;
# 4167198918391854712 Alice_PROPN 11516 11518 Alice felt
# 4167198918391854712 Alice_PROPN 11629 11631 Alice turned
# 4167198918391854712 Alice_PROPN 11651 11653 Alice,
# 4167198918391854712 Alice_PROPN 11673 11675 Alice thought
# 4167198918391854712 Alice_PROPN 11752 11754 Alice;
# 4167198918391854712 Alice_PROPN 11804 11806 Alice replied
# 4167198918391854712 Alice_PROPN 11826 11828 Alice folded
# 4167198918391854712 Alice_PROPN 12214 12216 Alice,
# 4167198918391854712 Alice_PROPN 12281 12283 Alice hastily
# 4167198918391854712 Alice_PROPN 12309 12311 Alice said
# 4167198918391854712 Alice_PROPN 12369 12371 Alice:
# 4167198918391854712 Alice_PROPN 12418 12420 Alice in
# 4167198918391854712 Alice_PROPN 12472 12474 Alice waited
# 4167198918391854712 Alice_PROPN 12564 12566 Alice to
# 4167198918391854712 Alice_PROPN 12855 12857 Alice in
# 4167198918391854712 Alice_PROPN 12934 12936 Alice.
# 4167198918391854712 Alice_PROPN 13129 13131 Alice indignantly
# 4167198918391854712 Alice_PROPN 13186 13188 Alice.
# 4167198918391854712 Alice_PROPN 13308 13310 Alice,
# 4167198918391854712 Alice_PROPN 13388 13390 Alice.
# 4167198918391854712 Alice_PROPN 13422 13424 Alice,
# 4167198918391854712 Alice_PROPN 13525 13527 Alice,
# 4167198918391854712 Alice_PROPN 13588 13590 Alice,
# 4167198918391854712 Alice_PROPN 13651 13653 Alice hastily
# 4167198918391854712 Alice_PROPN 13709 13711 Alice crouched
# 4167198918391854712 Alice_PROPN 13949 13951 Alice,
# 4167198918391854712 Alice_PROPN 14113 14115 Alice noticed
# 4167198918391854712 Alice_PROPN 14256 14258 Alice laughed
# 4167198918391854712 Alice_PROPN 14315 14317 Alice went
# 4167198918391854712 Alice_PROPN 14429 14431 Alice,
# 4167198918391854712 Alice_PROPN 14508 14510 Alice thought
# 4167198918391854712 Alice_PROPN 14652 14654 Alice again
# 4167198918391854712 Alice_PROPN 14770 14772 Alice.
# 4167198918391854712 Alice_PROPN 14799 14801 Alice desperately
# 4167198918391854712 Alice_PROPN 14887 14889 Alice said
# 4167198918391854712 Alice_PROPN 14981 14983 Alice,
# 4167198918391854712 Alice_PROPN 15039 15041 Alice quite
# 4167198918391854712 Alice_PROPN 15123 15125 Alice said
# 4167198918391854712 Alice_PROPN 15292 15294 Alice,
# 4167198918391854712 Alice_PROPN 15374 15376 Alice,
# 4167198918391854712 Alice_PROPN 15440 15442 Alice glanced
# 4167198918391854712 Alice_PROPN 15698 15700 Alice,
# 4167198918391854712 Alice_PROPN 15755 15757 Alice caught
# 4167198918391854712 Alice_PROPN 15795 15797 Alice.
# 4167198918391854712 Alice_PROPN 15925 15927 Alice,
# 4167198918391854712 Alice_PROPN 15980 15982 Alice;
# 4167198918391854712 Alice_PROPN 16000 16002 Alice looked
# 4167198918391854712 Alice_PROPN 16122 16124 Alice,
# 4167198918391854712 Alice_PROPN 16381 16383 Alice.
# 4167198918391854712 Alice_PROPN 16465 16467 Alice,
# 4167198918391854712 Alice_PROPN 16514 16516 Alice.
# 4167198918391854712 Alice_PROPN 16539 16541 Alice added
# 4167198918391854712 Alice_PROPN 16567 16569 Alice felt
# 4167198918391854712 Alice_PROPN 16652 16654 Alice remarked
# 4167198918391854712 Alice_PROPN 16687 16689 Alice.
# 4167198918391854712 Alice_PROPN 16706 16708 Alice didnât
# 4167198918391854712 Alice_PROPN 16754 16756 Alice.
# 4167198918391854712 Alice_PROPN 16819 16821 Alice.
# 4167198918391854712 Alice_PROPN 16854 16856 Alice,
# 4167198918391854712 Alice_PROPN 16945 16947 Alice quietly
# 4167198918391854712 Alice_PROPN 16978 16980 Alice waited
# 4167198918391854712 Alice_PROPN 17108 17110 Alice;
# 4167198918391854712 Alice_PROPN 17187 17189 Alice;
# 4167198918391854712 Alice_PROPN 17412 17414 Alice;
# 4167198918391854712 Alice_PROPN 17460 17462 Alice coming
# 4167198918391854712 Alice_PROPN 17470 17472 Alice indignantly
# 4167198918391854712 Alice_PROPN 17507 17509 Alice looked
# 4167198918391854712 Alice_PROPN 17559 17561 Alice angrily
# 4167198918391854712 Alice_PROPN 17596 17598 Alice;
# 4167198918391854712 Alice_PROPN 17625 17627 Alice for
# 4167198918391854712 Alice_PROPN 17652 17654 Alice said
# 4167198918391854712 Alice_PROPN 17702 17704 Alice.
# 4167198918391854712 Alice_PROPN 17749 17751 Alice.
# 4167198918391854712 Alice_PROPN 17772 17774 Alice hastily
# 4167198918391854712 Alice_PROPN 17930 17932 Alice thought
# 4167198918391854712 Alice_PROPN 17973 17975 Alice:
# 4167198918391854712 Alice_PROPN 18009 18011 Alice considered
# 4167198918391854712 Alice_PROPN 18209 18211 Alice replied
# 4167198918391854712 Alice_PROPN 18243 18245 Alice felt
# 4167198918391854712 Alice_PROPN 18354 18356 Alice
#
# 4167198918391854712 Alice_PROPN 18367 18369 Alice replied
# 4167198918391854712 Alice_PROPN 18396 18398 Alice sighed
# 4167198918391854712 Alice_PROPN 18466 18468 Alice.
# 4167198918391854712 Alice_PROPN 18497 18499 Alice cautiously
# 4167198918391854712 Alice_PROPN 18634 18636 Alice thoughtfully
# 4167198918391854712 Alice_PROPN 18685 18687 Alice asked
# 4167198918391854712 Alice_PROPN 18778 18780 Alice.
# 4167198918391854712 Alice_PROPN 18898 18900 Alice.
# 4167198918391854712 Alice_PROPN 18997 18999 Alice.
# 4167198918391854712 Alice_PROPN 19025 19027 Alice ventured
# 4167198918391854712 Alice_PROPN 19072 19074 Alice,
# 4167198918391854712 Alice_PROPN 19152 19154 Alice.
# 4167198918391854712 Alice_PROPN 19224 19226 Alice,
# 4167198918391854712 Alice_PROPN 19270 19272 Alice gently
# 4167198918391854712 Alice_PROPN 19293 19295 Alice tried
# 4167198918391854712 Alice_PROPN 19347 19349 Alice,
# 4167198918391854712 Alice_PROPN 19359 19361 Alice replied
# 4167198918391854712 Alice_PROPN 19405 19407 Alice.
# 4167198918391854712 Alice_PROPN 19543 19545 Alice said
# 4167198918391854712 Alice_PROPN 19600 19602 Alice,
# 4167198918391854712 Alice_PROPN 19666 19668 Alice rather
# 4167198918391854712 Alice_PROPN 19796 19798 Alice said
# 4167198918391854712 Alice_PROPN 19830 19832 Alice,
# 4167198918391854712 Alice_PROPN 19893 19895 Alice.
# 4167198918391854712 Alice_PROPN 20006 20008 Alice,
# 4167198918391854712 Alice_PROPN 20121 20123 Alice as
# 4167198918391854712 Alice_PROPN 20364 20366 Alice thought
# 4167198918391854712 Alice_PROPN 20553 20555 Alice,
# 4167198918391854712 Alice_PROPN 20590 20592 Alice,
# 4167198918391854712 Alice_PROPN 20744 20746 Alice looked
# 4167198918391854712 Alice_PROPN 20863 20865 Alice recognised
# 4167198918391854712 Alice_PROPN 21021 21023 Alice,
# 4167198918391854712 Alice_PROPN 21074 21076 Alice,
# 4167198918391854712 Alice_PROPN 21089 21091 Alice,
# 4167198918391854712 Alice_PROPN 21098 21100 Alice very
# 4167198918391854712 Alice_PROPN 21216 21218 Alice,
# 4167198918391854712 Alice_PROPN 21264 21266 Alice,
# 4167198918391854712 Alice_PROPN 21485 21487 Alice for
# 4167198918391854712 Alice_PROPN 21495 21497 Alice,
# 4167198918391854712 Alice_PROPN 21585 21587 Alice,
# 4167198918391854712 Alice_PROPN 21600 21602 Alice.
# 4167198918391854712 Alice_PROPN 21612 21614 Alice joined
# 4167198918391854712 Alice_PROPN 21662 21664 Alice:
# 4167198918391854712 Alice_PROPN 21720 21722 Alice.
# 4167198918391854712 Alice_PROPN 21741 21743 Alice:
# 4167198918391854712 Alice_PROPN 21767 21769 Alice gave
# 4167198918391854712 Alice_PROPN 21856 21858 Alice thought
# 4167198918391854712 Alice_PROPN 21919 21921 Alice found
# 4167198918391854712 Alice_PROPN 22100 22102 Alice
#
# 4167198918391854712 Alice_PROPN 22180 22182 Alice began
# 4167198918391854712 Alice_PROPN 22356 22358 Alice waited
# 4167198918391854712 Alice_PROPN 22402 22404 Alice put
# 4167198918391854712 Alice_PROPN 22463 22465 Alice began
# 4167198918391854712 Alice_PROPN 22586 22588 Alice:
# 4167198918391854712 Alice_PROPN 22647 22649 Alice,
# 4167198918391854712 Alice_PROPN 22671 22673 Alice:
# 4167198918391854712 Alice_PROPN 22737 22739 Alice as
# 4167198918391854712 Alice_PROPN 22753 22755 Alice.
# 4167198918391854712 Alice_PROPN 22858 22860 Alice thought
# 4167198918391854712 Alice_PROPN 22970 22972 Alice an
# 4167198918391854712 Alice_PROPN 23062 23064 Alice,
# 4167198918391854712 Alice_PROPN 23173 23175 Alice appeared
# 4167198918391854712 Alice_PROPN 23741 23743 Alice ventured
# 4167198918391854712 Alice_PROPN 23913 23915 Alice whispered
# 4167198918391854712 Alice_PROPN 23989 23991 Alice thought
# 4167198918391854712 Alice_PROPN 24046 24048 Alice cautiously
# 4167198918391854712 Alice_PROPN 24097 24099 Alice remarked
# 4167198918391854712 Alice_PROPN 24130 24132 Alice.
# 4167198918391854712 Alice_PROPN 24152 24154 Alice said
# 4167198918391854712 Alice_PROPN 24190 24192 Alice,
# 4167198918391854712 Alice_PROPN 24298 24300 Alice said
# 4167198918391854712 Alice_PROPN 24360 24362 Alice.
# 4167198918391854712 Alice_PROPN 24392 24394 Alice.
# 4167198918391854712 Alice_PROPN 24442 24444 Alice sharply
# 4167198918391854712 Alice_PROPN 24518 24520 Alice looked
# 4167198918391854712 Alice_PROPN 24632 24634 Alice;
# 4167198918391854712 Alice_PROPN 24798 24800 Alice,
# 4167198918391854712 Alice_PROPN 24825 24827 Alice,
# 4167198918391854712 Alice_PROPN 24840 24842 Alice.
# 4167198918391854712 Alice_PROPN 24880 24882 Alice.
# 4167198918391854712 Alice_PROPN 24909 24911 Alice heard
# 4167198918391854712 Alice_PROPN 25039 25041 Alice alone
# 4167198918391854712 Alice_PROPN 25127 25129 Alice.
# 4167198918391854712 Alice_PROPN 25137 25139 Alice.
# 4167198918391854712 Alice_PROPN 25175 25177 Alice,
# 4167198918391854712 Alice_PROPN 25389 25391 Alice thought
# 4167198918391854712 Alice_PROPN 25579 25581 Alice asked
# 4167198918391854712 Alice_PROPN 25637 25639 Alice,
# 4167198918391854712 Alice_PROPN 25703 25705 Alice.
# 4167198918391854712 Alice_PROPN 25765 25767 Alice;
# 4167198918391854712 Alice_PROPN 25792 25794 Alice,
# 4167198918391854712 Alice_PROPN 25811 25813 Alice indignantly
# 4167198918391854712 Alice_PROPN 25870 25872 Alice;
# 4167198918391854712 Alice_PROPN 25907 25909 Alice.
# 4167198918391854712 Alice_PROPN 25951 25953 Alice ventured
# 4167198918391854712 Alice_PROPN 25994 25996 Alice doubtfully
# 4167198918391854712 Alice_PROPN 26132 26134 Alice.
# 4167198918391854712 Alice_PROPN 26259 26261 Alice,
# 4167198918391854712 Alice_PROPN 26297 26299 Alice.
# 4167198918391854712 Alice_PROPN 26328 26330 Alice,
# 4167198918391854712 Alice_PROPN 26376 26378 Alice went
# 4167198918391854712 Alice_PROPN 26434 26436 Alice,
# 4167198918391854712 Alice_PROPN 26539 26541 Alice began
# 4167198918391854712 Alice_PROPN 26580 26582 Alice.
# 4167198918391854712 Alice_PROPN 26835 26837 Alice.
# 4167198918391854712 Alice_PROPN 26848 26850 Alice timidly
# 4167198918391854712 Alice_PROPN 26873 26875 Alice.
# 4167198918391854712 Alice_PROPN 26930 26932 Alice,
# 4167198918391854712 Alice_PROPN 27267 27269 Alice,
# 4167198918391854712 Alice_PROPN 27318 27320 Alice,
# 4167198918391854712 Alice_PROPN 27369 27371 Alice replied
# 4167198918391854712 Alice_PROPN 27518 27520 Alice,
# 4167198918391854712 Alice_PROPN 27570 27572 Alice.
# 4167198918391854712 Alice_PROPN 27630 27632 Alice looked
# 4167198918391854712 Alice_PROPN 27689 27691 Alice asked
# 4167198918391854712 Alice_PROPN 27730 27732 Alice,
# 4167198918391854712 Alice_PROPN 27794 27796 Alice in
# 4167198918391854712 Alice_PROPN 27846 27848 Alice.
# 4167198918391854712 Alice_PROPN 27894 27896 Alice a
# 4167198918391854712 Alice_PROPN 27954 27956 Alice began
# 4167198918391854712 Alice_PROPN 28132 28134 Alice.
# 4167198918391854712 Alice_PROPN 28165 28167 Alice;
# 4167198918391854712 Alice_PROPN 28373 28375 Alice said
# 4167198918391854712 Alice_PROPN 28469 28471 Alice said
# 4167198918391854712 Alice_PROPN 28757 28759 Alice
#
# 4167198918391854712 Alice_PROPN 28982 28984 Alice by
# 4167198918391854712 Alice_PROPN 29006 29008 Alice panted
# 4167198918391854712 Alice_PROPN 29186 29188 Alice quite
# 4167198918391854712 Alice_PROPN 29358 29360 Alice,
# 4167198918391854712 Alice_PROPN 29475 29477 Alice whispered
# 4167198918391854712 Alice_PROPN 29525 29527 Alice began
# 4167198918391854712 Alice_PROPN 29647 29649 Alice.
# 4167198918391854712 Alice_PROPN 29664 29666 Alice
#
# 4167198918391854712 Alice_PROPN 30259 30261 Alice felt
# 4167198918391854712 Alice_PROPN 30357 30359 Alice very
# 4167198918391854712 Alice_PROPN 30382 30384 Alice more
# 4167198918391854712 Alice_PROPN 30921 30923 Alice.
# 4167198918391854712 Alice_PROPN 31045 31047 Alice.
# 4167198918391854712 Alice_PROPN 31178 31180 Alice guessed
# 4167198918391854712 Alice_PROPN 31451 31453 Alice watched
# 4167198918391854712 Alice_PROPN 31526 31528 Alice,
# 4167198918391854712 Alice_PROPN 31725 31727 Alice as
# 4167198918391854712 Alice_PROPN 31732 31734 Alice looked
# 4167198918391854712 Alice_PROPN 31920 31922 Alice.
# 4167198918391854712 Alice_PROPN 31927 31929 Alice.
# 4167198918391854712 Alice_PROPN 31943 31945 Alice.
# 4167198918391854712 Alice_PROPN 32148 32150 Alice.
# 4167198918391854712 Alice_PROPN 32160 32162 Alice.
# 4167198918391854712 Alice_PROPN 32195 32197 Alice:
# 4167198918391854712 Alice_PROPN 32236 32238 Alice.
# 4167198918391854712 Alice_PROPN 32610 32612 Alice.
# 4167198918391854712 Alice_PROPN 32922 32924 Alice,
# 4167198918391854712 Alice_PROPN 33202 33204 Alice.
# 4167198918391854712 Alice_PROPN 33411 33413 Alice loudly
# 4167198918391854712 Alice_PROPN 33437 33439 Alice.
# 4167198918391854712 Alice_PROPN 33464 33466 Alice,
# 4167198918391854712 Alice_PROPN 33572 33574 Alice dear!â
# 4167198918391854712 Alice_PROPN 33597 33599 Alice,
# 4167198918391854712 Alice_PROPN 33670 33672 Alice got
# 4167198918391854712 Alice_PROPN 33725 33727 Alice and
# 4167198918391854712 Alice_PROPN 33757 33759 Alice herself

# %%
matcher = Matcher(nlp.vocab)

pattern = [{"LEMMA": "begin"}, {"POS":"ADP"}]

matcher.add('lemma_adp', [pattern])
matches = matcher(doc)

for match_id, start, end in (matches):
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(match_id, string_id, start, end, span.text)
# Out:
# 6308555498547242653 lemma_adp 11376 11378 begin with
# 6308555498547242653 lemma_adp 12231 12233 beginning to
# 6308555498547242653 lemma_adp 14157 14159 began by
# 6308555498547242653 lemma_adp 16731 16733 begin with
# 6308555498547242653 lemma_adp 17146 17148 beginning with
# 6308555498547242653 lemma_adp 19883 19885 begins with
# 6308555498547242653 lemma_adp 19952 19954 begins with
# 6308555498547242653 lemma_adp 20234 20236 began by
# 6308555498547242653 lemma_adp 20616 20618 began in
# 6308555498547242653 lemma_adp 23265 23267 begin at
# 6308555498547242653 lemma_adp 24553 24555 began in
# 6308555498547242653 lemma_adp 25918 25920 begin with
# 6308555498547242653 lemma_adp 29526 29528 began in
# 6308555498547242653 lemma_adp 30601 30603 begins with

# %% [markdown]
# # Phrase Matching

# %% [markdown]
# Matching exact phrases in the context

# %%
from spacy.matcher import PhraseMatcher
matcher = PhraseMatcher(nlp.vocab,attr='LOWER')
list_of_phrases = ['little','alice']

# Doc & make_doc are interchangable
pattern = [nlp.make_doc(text) for text in list_of_phrases]
matcher.add('little_magic',pattern)
matches = matcher(doc)

for match_id, start, end in (matches):
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(string_id, start, end, span.text)
# Out:
# little_magic 242 243 Little
# little_magic 323 324 Alice
# little_magic 384 385 Alice
# little_magic 472 473 Alice
# little_magic 567 568 Alice
# little_magic 646 647 Alice
# little_magic 690 691 Alice
# little_magic 884 885 Alice
# little_magic 1010 1011 Alice
# little_magic 1085 1086 Alice
# little_magic 1245 1246 little
# little_magic 1285 1286 Alice
# little_magic 1380 1381 Alice
# little_magic 1519 1520 Alice
# little_magic 1583 1584 Alice
# little_magic 1682 1683 Alice
# little_magic 1725 1726 little
# little_magic 1827 1828 little
# little_magic 1838 1839 little
# little_magic 1854 1855 Alice
# little_magic 1948 1949 Alice
# little_magic 1955 1956 little
# little_magic 2009 2010 Alice
# little_magic 2035 2036 little
# little_magic 2079 2080 little
# little_magic 2095 2096 Alice
# little_magic 2142 2143 little
# little_magic 2143 2144 Alice
# little_magic 2184 2185 little
# little_magic 2311 2312 Alice
# little_magic 2413 2414 Alice
# little_magic 2460 2461 little
# little_magic 2493 2494 little
# little_magic 2509 2510 Alice
# little_magic 2593 2594 Alice
# little_magic 2609 2610 little
# little_magic 2681 2682 little
# little_magic 2700 2701 Alice
# little_magic 2802 2803 Alice
# little_magic 2835 2836 little
# little_magic 2881 2882 Alice
# little_magic 2933 2934 little
# little_magic 2995 2996 Alice
# little_magic 3107 3108 Alice
# little_magic 3181 3182 little
# little_magic 3245 3246 Alice
# little_magic 3388 3389 little
# little_magic 3402 3403 Alice
# little_magic 3461 3462 Alice
# little_magic 3538 3539 little
# little_magic 3626 3627 Alice
# little_magic 3697 3698 Alice
# little_magic 3785 3786 little
# little_magic 3908 3909 little
# little_magic 4092 4093 little
# little_magic 4132 4133 little
# little_magic 4153 4154 Alice
# little_magic 4187 4188 little
# little_magic 4297 4298 Alice
# little_magic 4359 4360 little
# little_magic 4471 4472 Alice
# little_magic 4508 4509 little
# little_magic 4517 4518 little
# little_magic 4525 4526 little
# little_magic 4636 4637 Alice
# little_magic 4740 4741 Alice
# little_magic 4809 4810 little
# little_magic 4880 4881 Alice
# little_magic 4953 4954 Alice
# little_magic 5018 5019 little
# little_magic 5036 5037 Alice
# little_magic 5063 5064 Alice
# little_magic 5129 5130 Alice
# little_magic 5185 5186 Alice
# little_magic 5236 5237 Alice
# little_magic 5297 5298 Alice
# little_magic 5393 5394 Alice
# little_magic 5420 5421 Alice
# little_magic 5430 5431 little
# little_magic 5444 5445 little
# little_magic 5528 5529 Alice
# little_magic 5629 5630 Alice
# little_magic 5718 5719 Alice
# little_magic 5820 5821 Alice
# little_magic 5877 5878 Alice
# little_magic 5972 5973 Alice
# little_magic 6293 6294 Alice
# little_magic 6306 6307 Alice
# little_magic 6450 6451 Alice
# little_magic 6778 6779 Alice
# little_magic 6806 6807 Alice
# little_magic 6909 6910 Alice
# little_magic 6918 6919 Alice
# little_magic 6977 6978 Alice
# little_magic 7118 7119 Alice
# little_magic 7162 7163 Alice
# little_magic 7181 7182 Alice
# little_magic 7341 7342 Alice
# little_magic 7358 7359 Alice
# little_magic 7391 7392 Alice
# little_magic 7451 7452 Alice
# little_magic 7478 7479 Alice
# little_magic 7509 7510 little
# little_magic 7578 7579 little
# little_magic 7605 7606 Alice
# little_magic 7639 7640 Alice
# little_magic 7692 7693 little
# little_magic 7788 7789 Alice
# little_magic 7853 7854 Alice
# little_magic 7872 7873 little
# little_magic 7882 7883 little
# little_magic 7927 7928 Little
# little_magic 8007 8008 Alice
# little_magic 8073 8074 little
# little_magic 8086 8087 Alice
# little_magic 8141 8142 Alice
# little_magic 8229 8230 little
# little_magic 8302 8303 Alice
# little_magic 8339 8340 Alice
# little_magic 8378 8379 Alice
# little_magic 8411 8412 little
# little_magic 8473 8474 little
# little_magic 8566 8567 little
# little_magic 8777 8778 Alice
# little_magic 8780 8781 little
# little_magic 8843 8844 Alice
# little_magic 8990 8991 Alice
# little_magic 9136 9137 little
# little_magic 9144 9145 Alice
# little_magic 9235 9236 Alice
# little_magic 9258 9259 Alice
# little_magic 9306 9307 little
# little_magic 9504 9505 Alice
# little_magic 9568 9569 little
# little_magic 9590 9591 Alice
# little_magic 9649 9650 little
# little_magic 9814 9815 Alice
# little_magic 9882 9883 little
# little_magic 9997 9998 little
# little_magic 10010 10011 Alice
# little_magic 10087 10088 Alice
# little_magic 10115 10116 Alice
# little_magic 10157 10158 Alice
# little_magic 10178 10179 Alice
# little_magic 10196 10197 little
# little_magic 10248 10249 Alice
# little_magic 10261 10262 little
# little_magic 10372 10373 little
# little_magic 10381 10382 little
# little_magic 10418 10419 Alice
# little_magic 10457 10458 Alice
# little_magic 10553 10554 little
# little_magic 10598 10599 little
# little_magic 10602 10603 Alice
# little_magic 10668 10669 little
# little_magic 10718 10719 Alice
# little_magic 10770 10771 Alice
# little_magic 10825 10826 little
# little_magic 10878 10879 Alice
# little_magic 10926 10927 little
# little_magic 10931 10932 Alice
# little_magic 11032 11033 Alice
# little_magic 11202 11203 Alice
# little_magic 11257 11258 Alice
# little_magic 11332 11333 Alice
# little_magic 11363 11364 Alice
# little_magic 11414 11415 Alice
# little_magic 11447 11448 little
# little_magic 11475 11476 Alice
# little_magic 11516 11517 Alice
# little_magic 11519 11520 little
# little_magic 11575 11576 Alice
# little_magic 11629 11630 Alice
# little_magic 11651 11652 Alice
# little_magic 11673 11674 Alice
# little_magic 11752 11753 Alice
# little_magic 11793 11794 little
# little_magic 11804 11805 Alice
# little_magic 11826 11827 Alice
# little_magic 12214 12215 Alice
# little_magic 12281 12282 Alice
# little_magic 12309 12310 Alice
# little_magic 12355 12356 little
# little_magic 12369 12370 Alice
# little_magic 12418 12419 Alice
# little_magic 12472 12473 Alice
# little_magic 12564 12565 Alice
# little_magic 12600 12601 Alice
# little_magic 12685 12686 little
# little_magic 12855 12856 Alice
# little_magic 12934 12935 Alice
# little_magic 12981 12982 little
# little_magic 13129 13130 Alice
# little_magic 13186 13187 Alice
# little_magic 13228 13229 Alice
# little_magic 13308 13309 Alice
# little_magic 13388 13389 Alice
# little_magic 13417 13418 little
# little_magic 13422 13423 Alice
# little_magic 13464 13465 little
# little_magic 13525 13526 Alice
# little_magic 13536 13537 little
# little_magic 13588 13589 Alice
# little_magic 13636 13637 little
# little_magic 13651 13652 Alice
# little_magic 13709 13710 Alice
# little_magic 13933 13934 little
# little_magic 13949 13950 Alice
# little_magic 14113 14114 Alice
# little_magic 14143 14144 little
# little_magic 14226 14227 little
# little_magic 14256 14257 Alice
# little_magic 14315 14316 Alice
# little_magic 14429 14430 Alice
# little_magic 14508 14509 Alice
# little_magic 14652 14653 Alice
# little_magic 14689 14690 Alice
# little_magic 14770 14771 Alice
# little_magic 14799 14800 Alice
# little_magic 14887 14888 Alice
# little_magic 14981 14982 Alice
# little_magic 14984 14985 little
# little_magic 15039 15040 Alice
# little_magic 15123 15124 Alice
# little_magic 15155 15156 Alice
# little_magic 15292 15293 Alice
# little_magic 15374 15375 Alice
# little_magic 15389 15390 little
# little_magic 15440 15441 Alice
# little_magic 15558 15559 little
# little_magic 15629 15630 little
# little_magic 15636 15637 Alice
# little_magic 15698 15699 Alice
# little_magic 15755 15756 Alice
# little_magic 15771 15772 little
# little_magic 15795 15796 Alice
# little_magic 15799 15800 little
# little_magic 15925 15926 Alice
# little_magic 15958 15959 little
# little_magic 15980 15981 Alice
# little_magic 16000 16001 Alice
# little_magic 16058 16059 Alice
# little_magic 16122 16123 Alice
# little_magic 16140 16141 little
# little_magic 16168 16169 Alice
# little_magic 16259 16260 little
# little_magic 16353 16354 little
# little_magic 16381 16382 Alice
# little_magic 16452 16453 little
# little_magic 16465 16466 Alice
# little_magic 16514 16515 Alice
# little_magic 16539 16540 Alice
# little_magic 16567 16568 Alice
# little_magic 16652 16653 Alice
# little_magic 16687 16688 Alice
# little_magic 16706 16707 Alice
# little_magic 16754 16755 Alice
# little_magic 16819 16820 Alice
# little_magic 16854 16855 Alice
# little_magic 16878 16879 Alice
# little_magic 16945 16946 Alice
# little_magic 16978 16979 Alice
# little_magic 16981 16982 little
# little_magic 17108 17109 Alice
# little_magic 17187 17188 Alice
# little_magic 17412 17413 Alice
# little_magic 17460 17461 Alice
# little_magic 17470 17471 Alice
# little_magic 17507 17508 Alice
# little_magic 17559 17560 Alice
# little_magic 17596 17597 Alice
# little_magic 17625 17626 Alice
# little_magic 17652 17653 Alice
# little_magic 17702 17703 Alice
# little_magic 17749 17750 Alice
# little_magic 17772 17773 Alice
# little_magic 17930 17931 Alice
# little_magic 17973 17974 Alice
# little_magic 18009 18010 Alice
# little_magic 18012 18013 little
# little_magic 18148 18149 Alice
# little_magic 18209 18210 Alice
# little_magic 18243 18244 Alice
# little_magic 18302 18303 little
# little_magic 18354 18355 Alice
# little_magic 18367 18368 Alice
# little_magic 18396 18397 Alice
# little_magic 18466 18467 Alice
# little_magic 18497 18498 Alice
# little_magic 18634 18635 Alice
# little_magic 18685 18686 Alice
# little_magic 18752 18753 little
# little_magic 18778 18779 Alice
# little_magic 18898 18899 Alice
# little_magic 18997 18998 Alice
# little_magic 19025 19026 Alice
# little_magic 19072 19073 Alice
# little_magic 19152 19153 Alice
# little_magic 19183 19184 little
# little_magic 19224 19225 Alice
# little_magic 19270 19271 Alice
# little_magic 19293 19294 Alice
# little_magic 19347 19348 Alice
# little_magic 19359 19360 Alice
# little_magic 19405 19406 Alice
# little_magic 19419 19420 Alice
# little_magic 19498 19499 Alice
# little_magic 19543 19544 Alice
# little_magic 19584 19585 little
# little_magic 19600 19601 Alice
# little_magic 19666 19667 Alice
# little_magic 19694 19695 Alice
# little_magic 19721 19722 Alice
# little_magic 19796 19797 Alice
# little_magic 19830 19831 Alice
# little_magic 19893 19894 Alice
# little_magic 19904 19905 Alice
# little_magic 19944 19945 little
# little_magic 20006 20007 Alice
# little_magic 20035 20036 Alice
# little_magic 20121 20122 Alice
# little_magic 20213 20214 little
# little_magic 20238 20239 little
# little_magic 20289 20290 little
# little_magic 20364 20365 Alice
# little_magic 20553 20554 Alice
# little_magic 20590 20591 Alice
# little_magic 20593 20594 little
# little_magic 20744 20745 Alice
# little_magic 20827 20828 little
# little_magic 20863 20864 Alice
# little_magic 20931 20932 Alice
# little_magic 21021 21022 Alice
# little_magic 21074 21075 Alice
# little_magic 21089 21090 Alice
# little_magic 21098 21099 Alice
# little_magic 21216 21217 Alice
# little_magic 21264 21265 Alice
# little_magic 21485 21486 Alice
# little_magic 21495 21496 Alice
# little_magic 21585 21586 Alice
# little_magic 21600 21601 Alice
# little_magic 21612 21613 Alice
# little_magic 21662 21663 Alice
# little_magic 21720 21721 Alice
# little_magic 21741 21742 Alice
# little_magic 21767 21768 Alice
# little_magic 21770 21771 little
# little_magic 21856 21857 Alice
# little_magic 21919 21920 Alice
# little_magic 22100 22101 Alice
# little_magic 22180 22181 Alice
# little_magic 22356 22357 Alice
# little_magic 22402 22403 Alice
# little_magic 22463 22464 Alice
# little_magic 22586 22587 Alice
# little_magic 22647 22648 Alice
# little_magic 22671 22672 Alice
# little_magic 22737 22738 Alice
# little_magic 22753 22754 Alice
# little_magic 22858 22859 Alice
# little_magic 22970 22971 Alice
# little_magic 23005 23006 Alice
# little_magic 23062 23063 Alice
# little_magic 23099 23100 little
# little_magic 23173 23174 Alice
# little_magic 23348 23349 Alice
# little_magic 23507 23508 Alice
# little_magic 23681 23682 little
# little_magic 23741 23742 Alice
# little_magic 23783 23784 Alice
# little_magic 23877 23878 little
# little_magic 23913 23914 Alice
# little_magic 23947 23948 little
# little_magic 23989 23990 Alice
# little_magic 24046 24047 Alice
# little_magic 24097 24098 Alice
# little_magic 24130 24131 Alice
# little_magic 24152 24153 Alice
# little_magic 24190 24191 Alice
# little_magic 24298 24299 Alice
# little_magic 24360 24361 Alice
# little_magic 24392 24393 Alice
# little_magic 24430 24431 little
# little_magic 24442 24443 Alice
# little_magic 24453 24454 little
# little_magic 24518 24519 Alice
# little_magic 24632 24633 Alice
# little_magic 24635 24636 Alice
# little_magic 24798 24799 Alice
# little_magic 24825 24826 Alice
# little_magic 24840 24841 Alice
# little_magic 24880 24881 Alice
# little_magic 24909 24910 Alice
# little_magic 25039 25040 Alice
# little_magic 25046 25047 Alice
# little_magic 25127 25128 Alice
# little_magic 25137 25138 Alice
# little_magic 25175 25176 Alice
# little_magic 25220 25221 little
# little_magic 25233 25234 Alice
# little_magic 25389 25390 Alice
# little_magic 25473 25474 Alice
# little_magic 25523 25524 little
# little_magic 25542 25543 little
# little_magic 25579 25580 Alice
# little_magic 25637 25638 Alice
# little_magic 25703 25704 Alice
# little_magic 25724 25725 Alice
# little_magic 25765 25766 Alice
# little_magic 25784 25785 little
# little_magic 25792 25793 Alice
# little_magic 25811 25812 Alice
# little_magic 25870 25871 Alice
# little_magic 25907 25908 Alice
# little_magic 25951 25952 Alice
# little_magic 25994 25995 Alice
# little_magic 26027 26028 Alice
# little_magic 26132 26133 Alice
# little_magic 26259 26260 Alice
# little_magic 26297 26298 Alice
# little_magic 26328 26329 Alice
# little_magic 26336 26337 little
# little_magic 26376 26377 Alice
# little_magic 26434 26435 Alice
# little_magic 26539 26540 Alice
# little_magic 26580 26581 Alice
# little_magic 26835 26836 Alice
# little_magic 26848 26849 Alice
# little_magic 26858 26859 little
# little_magic 26873 26874 Alice
# little_magic 26930 26931 Alice
# little_magic 26976 26977 little
# little_magic 27267 27268 Alice
# little_magic 27318 27319 Alice
# little_magic 27369 27370 Alice
# little_magic 27518 27519 Alice
# little_magic 27570 27571 Alice
# little_magic 27587 27588 Alice
# little_magic 27630 27631 Alice
# little_magic 27639 27640 little
# little_magic 27689 27690 Alice
# little_magic 27730 27731 Alice
# little_magic 27794 27795 Alice
# little_magic 27846 27847 Alice
# little_magic 27894 27895 Alice
# little_magic 27896 27897 little
# little_magic 27954 27955 Alice
# little_magic 27975 27976 little
# little_magic 28132 28133 Alice
# little_magic 28165 28166 Alice
# little_magic 28373 28374 Alice
# little_magic 28469 28470 Alice
# little_magic 28512 28513 Alice
# little_magic 28701 28702 Alice
# little_magic 28757 28758 Alice
# little_magic 28982 28983 Alice
# little_magic 29006 29007 Alice
# little_magic 29093 29094 little
# little_magic 29186 29187 Alice
# little_magic 29238 29239 Alice
# little_magic 29358 29359 Alice
# little_magic 29431 29432 little
# little_magic 29475 29476 Alice
# little_magic 29525 29526 Alice
# little_magic 29573 29574 Alice
# little_magic 29647 29648 Alice
# little_magic 29664 29665 Alice
# little_magic 29704 29705 little
# little_magic 29758 29759 little
# little_magic 30259 30260 Alice
# little_magic 30357 30358 Alice
# little_magic 30382 30383 Alice
# little_magic 30921 30922 Alice
# little_magic 31045 31046 Alice
# little_magic 31178 31179 Alice
# little_magic 31451 31452 Alice
# little_magic 31510 31511 little
# little_magic 31526 31527 Alice
# little_magic 31725 31726 Alice
# little_magic 31732 31733 Alice
# little_magic 31761 31762 little
# little_magic 31836 31837 little
# little_magic 31920 31921 Alice
# little_magic 31927 31928 Alice
# little_magic 31943 31944 Alice
# little_magic 32064 32065 Alice
# little_magic 32148 32149 Alice
# little_magic 32160 32161 Alice
# little_magic 32195 32196 Alice
# little_magic 32236 32237 Alice
# little_magic 32610 32611 Alice
# little_magic 32922 32923 Alice
# little_magic 33202 33203 Alice
# little_magic 33278 33279 little
# little_magic 33411 33412 Alice
# little_magic 33437 33438 Alice
# little_magic 33464 33465 Alice
# little_magic 33510 33511 little
# little_magic 33572 33573 Alice
# little_magic 33597 33598 Alice
# little_magic 33670 33671 Alice
# little_magic 33724 33725 little
# little_magic 33725 33726 Alice
# little_magic 33756 33757 little
# little_magic 33757 33758 Alice
# little_magic 33798 33799 little
# little_magic 33844 33845 little
# little_magic 34125 34126 little
# little_magic 34175 34176 little

# %% [markdown]
# # Entity Matching

# %%
txt = """Here is the first volume in George R. R. Martin’s magnificent cycle of novels that includes A Clash of Kings and A Storm of Swords. As a whole, this series comprises a genuine masterpiece of modern fantasy, bringing together the best the genre has to offer. Magic, mystery, intrigue, romance, and adventure fill these pages and transport us to a world unlike any we have ever experienced. Already hailed as a classic, George R. R. Martin’s stunning series is destined to stand as one of the great achievements of imaginative fiction.

A GAME OF THRONES

Long ago, in a time forgotten, a preternatural event threw the seasons out of balance. In a land where summers can last decades and winters a lifetime, trouble is brewing. The cold is returning, and in the frozen wastes to the north of Winterfell, sinister and supernatural forces are massing beyond the kingdom’s protective Wall. At the center of the conflict lie the Starks of Winterfell, a family as harsh and unyielding as the land they were born to. Sweeping from a land of brutal cold to a distant summertime kingdom of epicurean plenty, here is a tale of lords and ladies, soldiers and sorcerers, assassins and bastards, who come together in a time of grim omens.

Here an enigmatic band of warriors bear swords of no human metal; a tribe of fierce wildlings carry men off into madness; a cruel young dragon prince barters his sister to win back his throne; and a determined woman undertakes the most treacherous of journeys. Amid plots and counterplots, tragedy and betrayal, victory and terror, the fate of the Starks, their allies, and their enemies hangs perilously in the balance, as each endeavors to win that deadliest of conflicts: the game of thrones."""

# %%
nlp = spacy.load('en_core_web_trf')

doc = nlp(txt)
displacy.render(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Here is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  volume in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George R. R. Martin’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  magnificent cycle of novels that includes
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A Clash of Kings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  and
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A Storm of Swords
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# . As a whole, this series comprises a genuine masterpiece of modern fantasy, bringing together the best the genre has to offer. Magic, mystery, intrigue, romance, and adventure fill these pages and transport us to a world unlike any we have ever experienced. Already hailed as a classic,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     George R. R. Martin’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  stunning series is destined to stand as one of the great achievements of imaginative fiction.</br></br>A GAME OF THRONES</br></br>Long ago, in a time forgotten, a preternatural event threw the seasons out of balance. In a land where
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     summers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  can last
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     winters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  a lifetime, trouble is brewing. The cold is returning, and in the frozen wastes to the north of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winterfell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , sinister and supernatural forces are massing beyond the kingdom’s protective
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# . At the center of the conflict lie the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Starks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Winterfell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , a family as harsh and unyielding as the land they were born to. Sweeping from a land of brutal cold to a distant
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     summertime
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  kingdom of epicurean plenty, here is a tale of lords and ladies, soldiers and sorcerers, assassins and bastards, who come together in a time of grim omens.</br></br>Here an enigmatic band of warriors bear swords of no human metal; a tribe of fierce wildlings carry men off into madness; a cruel young dragon prince barters his sister to win back his throne; and a determined woman undertakes the most treacherous of journeys. Amid plots and counterplots, tragedy and betrayal, victory and terror, the fate of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Starks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , their allies, and their enemies hangs perilously in the balance, as each endeavors to win that deadliest of conflicts: the game of thrones.</div></span>

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.bbc.com/news/business-61589229"
html_content = requests.get(url).text

soup = BeautifulSoup(html_content,'lxml')
txt = soup.body.text

# %%
nlp = spacy.load('en_core_web_trf')

doc = nlp(txt)
displacy.render(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">BBC HomepageSkip to contentAccessibility HelpYour accountHomeNewsSportReelWorklifeTravelFutureMore menuMore menuSearch BBCHomeNewsSportReelWorklifeTravelFutureCultureMusicTVWeatherSoundsClose menuBBC NewsMenuHomeWar in UkraineCoronavirusClimateVideoWorldAsiaUKBusinessTechMoreScienceStoriesEntertainment &amp; ArtsHealthWorld News TVIn PicturesReality CheckNewsbeatLong ReadsBusinessMarket DataNew EconomyNew Tech EconomyCompaniesTechnology of BusinessEconomyCEO SecretsGlobal TradeCost of LivingTwitter investor sues
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and platform over takeover bidPublished27
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 2022Shareclose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  panelShare pageCopy linkAbout sharingImage source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty ImagesBy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Annabelle  LiangBusiness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reporterA
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  investor is suing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the social media platform over the handling of the billionaire's
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $44bn (Â£34.9bn) bid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  for the company. The case alleges he violated
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  corporate laws in a number of ways.It accuses the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  boss of &quot;wrongful conduct&quot; as his &quot;false statements and market manipulation have created 'chaos' at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's headquarters in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco&quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shares are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 27%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  lower than Mr
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     54.20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  offer price.The proposed class action lawsuit was filed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the US District Court for the Northern District of California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by investor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Heresniak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who said he was acting &quot;on behalf of himself and all others similarly situated&quot;.A class-action is a lawsuit that has been filed or is defended by an individual acting on behalf of a group of people.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  warns
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  deal stuck without spam proofTwitter hits back on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  doubts over fake accountsTwitter executives ousted ahead of
# <mark class="entity" style="background: #aa9cfc; p

# %% [markdown]
# # Word2Vec

# %%
#!python -m spacy download en_core_web_lg #685k unique vectors
nlp = spacy.load('en_core_web_lg')

# %%
t1 = nlp('i want tea')
t2 = nlp('i want coffee')

t1.similarity(t2)
# Out:
# 0.9576329871632303
